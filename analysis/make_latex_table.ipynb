# %% [markdown]
# # Astrometry

# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
from lenstronomy.Plots.model_plot import ModelPlot
import pickle 
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.io import fits

# define filters and system names
names = ['J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027', 'J1442+4055', 'J1515+1511', 'J1620+1203', 'J2325-5229']
filter = 'F814W'

# table format:
# Lens System Name, RA_lens, Dec_lens, RA_im1, Dec_im1, Ra_im2, Dec_im2, Image Separation [arcsec]
print("\\begin{tabular}{lccccccc}")
print("\\hline")
print("Lens System & RA & DEC & RA$_{im1}$ & DEC$_{im1}$ & RA$_{im2}$ & DEC$_{im2}$ & Separation [arcsec]\\\\")
print("\\hline")

for i, name in enumerate(names):
    filename = f"../joint_modeling/{name}/{name}_joint.pkl"

    with open(filename, "rb") as f:
        loaded_data = pickle.load(f)

    kwargs_result = loaded_data["kwargs_result"]

    ra_lens = kwargs_result['kwargs_lens'][0]['center_x']
    dec_lens = kwargs_result['kwargs_lens'][0]['center_y']

    ra_im1 = kwargs_result['kwargs_ps'][0]['ra_image'][0] - ra_lens
    dec_im1 = kwargs_result['kwargs_ps'][0]['dec_image'][0] - dec_lens

    ra_im2 = kwargs_result['kwargs_ps'][0]['ra_image'][1] - ra_lens
    dec_im2 = kwargs_result['kwargs_ps'][0]['dec_image'][1] - dec_lens

    image_sep = np.sqrt((ra_im1 - ra_im2)**2 + (dec_im1 - dec_im2)**2)

    filename = f'../cutout_data/{name}/F814W/{name}_F814W_cutout.fits'
    hdul = fits.open(filename)
    header = hdul[0].header
    
    ra_deg = header['RA_TARG']
    dec_deg = header['DEC_TARG']
    
    coord = SkyCoord(ra=ra_deg*u.deg, dec=dec_deg*u.deg)
    
    # Keep RA and DEC to 5 significant digits
    RA = coord.ra.to_string(unit=u.hour, sep=':', precision=3)
    DEC = coord.dec.to_string(unit=u.deg, sep=':', precision=3)

    print(f"{name} & {RA} & {DEC} & {ra_im1:.3f} & {dec_im1:.3f} & {ra_im2:.3f} & {dec_im2:.3f} & {image_sep:.3f} \\\\")

print("\\hline")
print("\\end{tabular}")
# Out:
# \begin{tabular}{lccccccc}
# \hline
# Lens System & RA & DEC & RA$_{im1}$ & DEC$_{im1}$ & RA$_{im2}$ & DEC$_{im2}$ & Separation [arcsec]\\
# \hline
# J0407-5006 & 4:07:10.272 & -50:06:01.510 & -0.146 & -0.198 & 0.702 & 1.279 & 1.703 \\
# J0602-4335 & 6:02:16.100 & -43:35:40.200 & -0.761 & -0.925 & 0.414 & 0.475 & 1.827 \\
# J0806+2006 & 8:06:23.680 & 20:06:31.460 & -0.915 & 0.472 & 0.407 & -0.198 & 1.482 \\
# J1001+5027 & 10:01:28.500 & 50:27:57.420 & -2.047 & -1.097 & 0.444 & 0.439 & 2.927 \\
# J1442+4055 & 14:42:54.700 & 40:55:35.620 & -1.291 & 0.396 & 0.766 & -0.166 & 2.133 \\
# J1515+1511 & 15:15:38.540 & 15:11:35.120 & -1.178 & 0.807 & 0.491 & -0.304 & 2.005 \\
# J1620+1203 & 16:20:26.234 & 12:03:40.680 & -0.306 & -0.416 & 1.779 & 1.472 & 2.812 \\
# J2325-5229 & 23:25:41.210 & -52:29:15.000 & -0.502 & 1.655 & 0.910 & -0.791 & 2.824 \\
# \hline
# \end{tabular}

# %% [markdown]
# # Magnitude Table

# %%
import h5py
import numpy as np
import os

# Define system names
names = ['J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027',
         'J1442+4055', 'J1515+1511', 'J1620+1203', 'J2325-5229']

def flux_ratio_and_sigma(fA, fB, sigmaA, sigmaB):
    """Compute flux ratio fA/fB with asymmetric errors."""
    ratio = fA / fB
    sigmaA_upper, sigmaA_lower = sigmaA
    sigmaB_upper, sigmaB_lower = sigmaB
    sigmaR_upper = ratio * np.sqrt((sigmaA_upper / fA)**2 + (sigmaB_lower / fB)**2)
    sigmaR_lower = ratio * np.sqrt((sigmaA_lower / fA)**2 + (sigmaB_upper / fB)**2)
    return ratio, sigmaR_upper, sigmaR_lower

def format_quantity(val, upper, lower, decimals=2):
    return f"${val:.{decimals}f}^{{+{upper:.{decimals}f}}}_{{-{lower:.{decimals}f}}}$"

def mag_sigma(flux, sigma_flux, zp_err_mag=0.018):
    sigma_flux = np.asarray(sigma_flux)
    sigma_upper = sigma_flux[0]
    sigma_lower = sigma_flux[1]
    zp_flux_err = 0.921 * flux * zp_err_mag
    total_upper = np.sqrt(sigma_upper**2 + zp_flux_err**2)
    total_lower = np.sqrt(sigma_lower**2 + zp_flux_err**2)
    mag_err_upper = (2.5 / np.log(10)) * (total_upper / flux)
    mag_err_lower = (2.5 / np.log(10)) * (total_lower / flux)
    return mag_err_upper, mag_err_lower

def format_mag(mag, sigmas):
    return f"${mag:.2f}^{{+{sigmas[0]:.2f}}}_{{-{sigmas[1]:.2f}}}$"

# --- LaTeX header ---
print("\\begin{tabular*}{\\textwidth}{@{\\extracolsep{\\fill}}lccccccc}")
print("\\hline")
print("Lens System & Filter & Lens & Image A & Image B & Host (lensed) & Host (delensed) & $f_A/f_B$ \\\\")
print("\\hline")

# --- Loop over systems ---
for name in names:
    for filt in ["F160W", "F814W", "F475X"]:
        filename = f"../joint_modeling/{name}/{name}_photometry.hdf5"

        if not os.path.exists(filename):
            print(f"{name} & {filt} & -- & -- & -- & -- & -- & -- \\\\")
            continue

        with h5py.File(filename, "r") as f:
            if filt not in f:
                print(f"{name} & {filt} & -- & -- & -- & -- & -- & -- \\\\")
                continue
            g = f[filt]

            def get_component_row(label_prefix):
                if f"{label_prefix}_flux" not in g:
                    return "--"
                flux = g[f"{label_prefix}_flux"][()]
                flux_sigma = g[f"{label_prefix}_flux_sigma"][()]
                mag = g[f"{label_prefix}_mag"][()]
                return format_mag(mag, mag_sigma(flux, flux_sigma))

            fA = g["image1_flux"][()]
            fB = g["image2_flux"][()]
            sigmaA = g["image1_flux_sigma"][()]
            sigmaB = g["image2_flux_sigma"][()]
            magA = g["image1_mag"][()]
            magB = g["image2_mag"][()]
            magA_fmt = format_mag(magA, mag_sigma(fA, sigmaA))
            magB_fmt = format_mag(magB, mag_sigma(fB, sigmaB))
            ratio, r_up, r_low = flux_ratio_and_sigma(fA, fB, sigmaA, sigmaB)
            flux_ratio_fmt = format_quantity(ratio, r_up, r_low)

            # --- Hosts ---
            def get_host(label):
                """Return formatted host magnitude or N/A if NaN."""
                mag_key = f"host_{label}_mag"
                flux_key = f"host_{label}_flux"
                flux_sigma_key = f"host_{label}_flux_sigma"

                if mag_key not in g:
                    return "--"

                mag = g[mag_key][()]
                if np.isnan(mag):
                    return "N/A"

                flux = g[flux_key][()]
                flux_sigma = g[flux_sigma_key][()]
                return format_mag(mag, mag_sigma(flux, flux_sigma))

            host_lensed_fmt = get_host("lensed")
            host_intrinsic_fmt = get_host("intrinsic")

            lens_mag_fmt = get_component_row("lens")

            if filt == 'F160W':
                print(f"{name} & {filt} & {lens_mag_fmt} & {magA_fmt} & {magB_fmt} & {host_lensed_fmt} & {host_intrinsic_fmt} & {flux_ratio_fmt} \\\\")
            else:
                print(f" & {filt} & {lens_mag_fmt} & {magA_fmt} & {magB_fmt} & {host_lensed_fmt} & {host_intrinsic_fmt} & {flux_ratio_fmt} \\\\")

            if name == "J1001+5027" and f"{'perturber_flux'}" in g:
                pert_mag_fmt = get_component_row("perturber")
                print(f"Perturber & {filt} & {pert_mag_fmt} & -- & -- & -- & -- & -- \\\\")

    print("\\hline")

print("\\end{tabular*}")
# Out:
# \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}lccccccc}
# \hline
# Lens System & Filter & Lens & Image A & Image B & Host (lensed) & Host (delensed) & $f_A/f_B$ \\
# \hline
# J0407-5006 & F160W & $18.99^{+0.02}_{-0.02}$ & $19.31^{+0.02}_{-0.02}$ & $18.19^{+0.02}_{-0.02}$ & $19.82^{+0.03}_{-0.03}$ & $20.88^{+0.04}_{-0.04}$ & $0.36^{+0.00}_{-0.00}$ \\
#  & F814W & $20.00^{+0.02}_{-0.02}$ & $19.74^{+0.02}_{-0.02}$ & $18.31^{+0.02}_{-0.02}$ & $21.52^{+0.04}_{-0.04}$ & $22.58^{+0.05}_{-0.05}$ & $0.27^{+0.00}_{-0.00}$ \\
#  & F475X & $21.62^{+0.03}_{-0.04}$ & $19.93^{+0.02}_{-0.02}$ & $18.63^{+0.02}_{-0.02}$ & $22.74^{+0.04}_{-0.03}$ & $23.80^{+0.04}_{-0.04}$ & $0.30^{+0.00}_{-0.00}$ \\
# \hline
# J0602-4335 & F160W & $17.80^{+0.02}_{-0.02}$ & $19.47^{+0.02}_{-0.02}$ & $19.26^{+0.02}_{-0.02}$ & $20.97^{+0.03}_{-0.02}$ & $22.76^{+0.04}_{-0.04}$ & $0.82^{+0.01}_{-0.01}$ \\
#  & F814W & $18.88^{+0.02}_{-0.02}$ & $19.64^{+0.02}_{-0.02}$ & $19.45^{+0.02}_{-0.02}$ & $24.58^{+0.21}_{-0.19}$ & $26.28^{+0.19}_{-0.18}$ & $0.84^{+0.00}_{-0.00}$ \\
#  & F475X & $20.66^{+0.02}_{-0.02}$ & $19.86^{+0.02}_{-0.02}$ & $19.66^{+0.02}_{-0.02}$ & $25.75^{+0.22}_{-0.21}$ & $27.42^{+0.23}_{-0.21}$ & $0.83^{+0.00}_{-0.00}$ \\
# \hline
# J0806+2006 & F160W & $18.48^{+0.02}_{-0.02}$ & $18.89^{+0.02}_{-0.02}$ & $19.96^{+0.02}_{-0.02}$ & $21.10^{+0.07}_{-0.07}$ & $22.32^{+0.07}_{-0.07}$ & $2.67^{+0.03}_{-0.03}$ \\
#  & F814W & $19.67^{+0.03}_{-0.03}$ & $19.17^{+0.02}_{-0.02}$ & $19.74^{+0.02}_{-0.02}$ & N/A & N/A & $1.69^{+0.01}_{-0.01}$ \\
#  & F475X & $23.18^{+0.08}_{-0.06}$ & $20.04^{+0.02}_{-0.02}$ & $20.48^{+0.02}_{-0.02}$ & N/A & N/A & $1.50^{+0.01}_{-0.01}$ \\
# \hline
# J1001+5027 & F160W & $18.14^{+0.02}_{-0.02}$ & $18.15^{+0.02}_{-0.02}$ & $17.98^{+0.02}_{-0.02}$ & $19.14^{+0.02}_{-0.02}$ & $21.11^{+0.03}_{-0.03}$ & $0.85^{+0.01}_{-0.01}$ \\
#  & F814W & $19.34^{+0.02}_{-0.02}$ & $17.68^{+0.02}_{-0.02}$ & $17.63^{+0.02}_{-0.02}$ & N/A & N/A & $0.96^{+0.00}_{-0.00}$ \\
#  & F475X & $21.59^{+0.02}_{-0.02}$ & $18.15^{+0.02}_{-0.02}$ & $18.13^{+0.02}_{-0.02}$ & $22.01^{+0.02}_{-0.02}$ & $23.98^{+0.03}_{-0.03}$ & $0.98^{+0.00}_{-0.00}$ \\
# \hline
# J1442+4055 & F160W & $18.07^{+0.02}_{-0.02}$ & $17.96^{+0.02}_{-0.02}$ & $18.49^{+0.02}_{-0.02}$ & $19.64^{+0.03}_{-0.03}$ & $21.80^{+0.04}_{-0.04}$ & $1.63^{+0.01}_{-0.01}$ \\
#  & F814W & $18.84^{+0.02}_{-0.02}$ & $18.19^{+0.02}_{-0.02}$ & $18.92^{+0.02}_{-0.02}$ & N/A & N/A & $1.97^{+0.01}_{-0.01}$ \\
#  & F475X & $20.58^{+0.02}_{-0.02}$ & $18.89^{+0.02}_{-0.02}$ & $19.79^{+0.02}_{-0.02}$ & $23.63^{+0.10}_{-0.09}$ & $25.80^{+0.10}_{-0.10}$ & $2.28^{+0.01}_{-0.01}$ \\
# \hline
# J1515+1511 & F160W & $19.69^{+0.02}_{-0.02}$ & $18.14^{+0.02}_{-0.02}$ & $18.50^{+0.02}_{-0.02}$ & $21.15^{+0.05}_{-0.05}$ & $22.58^{+0.06}_{-0.06}$ & $1.39^{+0.01}_{-0.01}$ \\
#  & F814W & $21.66^{+0.03}_{-0.03}$ & $18.16^{+0.02}_{-0.02}$ & $18.50^{+0.02}_{-0.02}$ & $23.29^{+0.10}_{-0.13}$ & $24.72^{+0.09}_{-0.11}$ & $1.37^{+0.00}_{-0.00}$ \\
#  & F475X & $22.03^{+0.06}_{-0.06}$ & $18.76^{+0.02}_{-0.02}$ & $19.27^{+0.02}_{-0.02}$ & $23.74^{+0.10}_{-0.09}$ & $25.17^{+0.14}_{-0.11}$ & $1.60^{+0.00}_{-0.00}$ \\
# \hline
# J1620+1203 & F160W & $17.37^{+0.02}_{-0.02}$ & $20.86^{+0.03}_{-0.03}$ & $18.80^{+0.02}_{-0.02}$ & $20.65^{+0.04}_{-0.04}$ & $22.00^{+0.05}_{-0.05}$ & $0.15^{+0.00}_{-0.00}$ \\
#  & F814W & $18.60^{+0.02}_{-0.02}$ & $20.41^{+0.02}_{-0.02}$ & $18.99^{+0.02}_{-0.02}$ & $22.75^{+0.05}_{-0.04}$ & $24.10^{+0.05}_{-0.05}$ & $0.27^{+0.00}_{-0.00}$ \\
#  & F475X & $20.72^{+0.02}_{-0.02}$ & $21.17^{+0.02}_{-0.02}$ & $19.69^{+0.02}_{-0.02}$ & $22.94^{+0.04}_{-0.05}$ & $24.29^{+0.05}_{-0.06}$ & $0.26^{+0.00}_{-0.00}$ \\
# \hline
# J2325-5229 & F160W & $17.78^{+0.02}_{-0.02}$ & $20.13^{+0.02}_{-0.02}$ & $20.59^{+0.02}_{-0.02}$ & $19.38^{+0.04}_{-0.04}$ & $20.78^{+0.06}_{-0.05}$ & $1.53^{+0.01}_{-0.01}$ \\
#  & F814W & $18.63^{+0.02}_{-0.02}$ & $20.89^{+0.02}_{-0.02}$ & $21.27^{+0.02}_{-0.02}$ & N/A & N/A & $1.41^{+0.01}_{-0.01}$ \\
#  & F475X & $20.88^{+0.09}_{-0.05}$ & $21.03^{+0.02}_{-0.02}$ & $21.28^{+0.02}_{-0.02}$ & N/A & N/A & $1.26^{+0.01}_{-0.01}$ \\
# \hline
# \end{tabular*}

# %% [markdown]
# # Lens Light Parameter Table

# %%
import pickle
import numpy as np
import os
from lenstronomy.Util.param_util import ellipticity2phi_q

names = ['J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027', 'J1442+4055', 'J1515+1511', 'J1620+1203', 'J2325-5229']

def get_median_and_uncertainties(samples):
    median = np.percentile(samples, 50)
    lower = median - np.percentile(samples, 16)
    upper = np.percentile(samples, 84) - median
    return median, lower, upper

def get_median_and_uncertainties_with_floor(
    samples,
    frac_floor=0.02,
    abs_floor=0.005  # arcsec
):
    """Compute uncertainties with a 2% floor, used in
    Sersic radius computation."""
    median = np.percentile(samples, 50)

    lo_stat = median - np.percentile(samples, 16)
    up_stat = np.percentile(samples, 84) - median

    # Systematic floor: relative OR absolute, whichever is larger
    floor = max(frac_floor * median, abs_floor)

    lo = np.sqrt(lo_stat**2 + floor**2)
    up = np.sqrt(up_stat**2 + floor**2)

    return median, lo, up


def format_val(med, lo, up, fmt=".2f"):
    return f"${med:{fmt}}^{{+{up:{fmt}}}}_{{-{lo:{fmt}}}}$"

def extract_profile(samples, param_names, param_mcmc):
    """Return R, n, q, phi chains for one profile."""
    idx = [param_mcmc.index(p) for p in param_names]
    r_chain = samples[:, idx[0]]
    n_chain = samples[:, idx[1]]
    e1_chain = samples[:, idx[2]]
    e2_chain = samples[:, idx[3]]
    phi_chain, q_chain = ellipticity2phi_q(e1_chain, e2_chain)
    phi_chain = (phi_chain * 180 / np.pi) % 180
    return r_chain, n_chain, q_chain, phi_chain

def summarize_chain(chain, fmt=".2f"):
    med, lo, up = get_median_and_uncertainties(chain)
    return format_val(med, lo, up, fmt)

def summarize_chain_with_floor(chain, fmt=".2f", frac_floor=0.02):
    med, lo, up = get_median_and_uncertainties_with_floor(chain, frac_floor)
    return format_val(med, lo, up, fmt)

# Filter maps for each system 
default_filter_map = {
    "F160W": [0, 1],
    "F814W": [2],
    "F475X": [3],
}

# Special case: J0602 has 2 lens light profiles per band
j0602_filter_map = {
    "F160W": [0, 1],
    "F814W": [2, 3],
    "F475X": [4, 5],
}

# Special case: J1001 has 1 lens + 1 perturber per band
j1001_filter_map = {
    "F160W": {"lens": [0], "perturber": [1]},
    "F814W": {"lens": [2], "perturber": [3]},
    "F475X": {"lens": [4], "perturber": [5]},
}

# LaTeX header
print("\\begin{tabular*}{\\textwidth}{@{\\extracolsep{\\fill}}lccccc}")
print("\\hline")
print("Lens System & Filter & $R_{\\text{S\\'ersic}}$ [arcsec] & "
      "$n_{\\text{S\\'ersic}}$ & $q$ & $\\phi_{\\text{ext}}$ [deg] \\\\")
print("\\hline")

# Loop over systems
for name in names:
    filename = f"../joint_modeling/{name}/{name}_joint.pkl"
    if not os.path.exists(filename):
        print(f"{name} & -- & -- & -- & -- & -- \\\\")
        print("\\hline")
        continue

    with open(filename, "rb") as f:
        loaded_data = pickle.load(f)

    chain_list = loaded_data.get("chain_list")
    sampler_type, samples, param_mcmc, dist_mcmc = chain_list[3]

    # Select appropriate filter map
    if name == "J0602-4335":
        filter_map = j0602_filter_map
    elif name == "J1001+5027":
        filter_map = j1001_filter_map
    else:
        filter_map = default_filter_map

    row_started = False
    for filt in ["F160W", "F814W", "F475X"]:
        if name == "J1001+5027":
            # Handle both lens and perturber for J1001
            for comp_label, prof_indices in filter_map[filt].items():
                for prof_idx in prof_indices:
                    try:
                        param_names = [
                            f"R_sersic_lens_light{prof_idx}",
                            f"n_sersic_lens_light{prof_idx}",
                            f"e1_lens_light{prof_idx}",
                            f"e2_lens_light{prof_idx}"
                        ]

                        r_chain, n_chain, q_chain, phi_chain = extract_profile(samples, param_names, param_mcmc)

                        r_str = summarize_chain(r_chain)
                        n_str = summarize_chain(n_chain)
                        q_str = summarize_chain(q_chain)
                        phi_str = summarize_chain(phi_chain, fmt=".1f")

                        label_prefix = "Lens" if comp_label == "lens" else "Perturber"
                        if not row_started:
                            print(f"{name} & {filt} ({label_prefix}) & {r_str} & {n_str} & {q_str} & {phi_str} \\\\")
                            row_started = True
                        else:
                            print(f" & {filt} ({label_prefix}) & {r_str} & {n_str} & {q_str} & {phi_str} \\\\")
                    except Exception:
                        label_prefix = "Lens" if comp_label == "lens" else "Perturber"
                        if not row_started:
                            print(f"{name} & {filt} ({label_prefix}) & -- & -- & -- & -- \\\\")
                            row_started = True
                        else:
                            print(f" & {filt} ({label_prefix}) & -- & -- & -- & -- \\\\")

        else:
            # Default behavior for other systems
            prof_indices = filter_map.get(filt, [])
            if not prof_indices:
                continue

            for prof_idx in prof_indices:
                try:
                    param_names = [
                        f"R_sersic_lens_light{prof_idx}",
                        f"n_sersic_lens_light{prof_idx}",
                        f"e1_lens_light{prof_idx}",
                        f"e2_lens_light{prof_idx}"
                    ]

                    r_chain, n_chain, q_chain, phi_chain = extract_profile(samples, param_names, param_mcmc)

                    r_str = summarize_chain_with_floor(r_chain, frac_floor=0.02)
                    n_str = summarize_chain(n_chain)
                    q_str = summarize_chain(q_chain)
                    phi_str = summarize_chain(phi_chain, fmt=".1f")

                    if not row_started:
                        print(f"{name} & {filt} & {r_str} & {n_str} & {q_str} & {phi_str} \\\\")
                        row_started = True
                    else:
                        print(f" & {filt} & {r_str} & {n_str} & {q_str} & {phi_str} \\\\")
                except Exception:
                    if not row_started:
                        print(f"{name} & {filt} & -- & -- & -- & -- \\\\")
                        row_started = True
                    else:
                        print(f" & {filt} & -- & -- & -- & -- \\\\")

    print("\\hline")

print("\\end{tabular*}")
# Out:
# \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}lccccc}
# \hline
# Lens System & Filter & $R_{\text{S\'ersic}}$ [arcsec] & $n_{\text{S\'ersic}}$ & $q$ & $\phi_{\text{ext}}$ [deg] \\
# \hline
# J0407-5006 & F160W & $0.13^{+0.01}_{-0.01}$ & $5.94^{+0.04}_{-0.08}$ & $0.39^{+0.01}_{-0.01}$ & $175.3^{+0.5}_{-0.5}$ \\
#  & F160W & $0.71^{+0.02}_{-0.02}$ & $1.03^{+0.06}_{-0.05}$ & $0.46^{+0.01}_{-0.01}$ & $141.1^{+1.0}_{-0.9}$ \\
#  & F814W & $0.72^{+0.03}_{-0.03}$ & $5.95^{+0.04}_{-0.06}$ & $0.74^{+0.01}_{-0.01}$ & $178.1^{+1.3}_{-177.2}$ \\
#  & F475X & $4.70^{+0.16}_{-0.42}$ & $5.95^{+0.03}_{-0.04}$ & $0.71^{+0.04}_{-0.03}$ & $62.7^{+2.6}_{-2.8}$ \\
# \hline
# J0602-4335 & F160W & $0.58^{+0.01}_{-0.01}$ & $0.80^{+0.01}_{-0.01}$ & $0.13^{+0.00}_{-0.00}$ & $133.6^{+0.0}_{-0.0}$ \\
#  & F160W & $0.17^{+0.01}_{-0.01}$ & $2.21^{+0.02}_{-0.02}$ & $0.67^{+0.00}_{-0.00}$ & $141.4^{+0.2}_{-0.2}$ \\
#  & F814W & $0.60^{+0.01}_{-0.01}$ & $0.82^{+0.02}_{-0.02}$ & $0.11^{+0.00}_{-0.00}$ & $133.9^{+0.1}_{-0.1}$ \\
#  & F814W & $0.23^{+0.01}_{-0.01}$ & $1.93^{+0.02}_{-0.02}$ & $0.75^{+0.01}_{-0.01}$ & $139.1^{+0.7}_{-0.7}$ \\
#  & F475X & $0.68^{+0.02}_{-0.02}$ & $0.78^{+0.03}_{-0.03}$ & $0.09^{+0.00}_{-0.00}$ & $134.3^{+0.1}_{-0.1}$ \\
#  & F475X & $0.22^{+0.01}_{-0.01}$ & $1.30^{+0.03}_{-0.03}$ & $0.86^{+0.01}_{-0.01}$ & $149.3^{+2.9}_{-2.9}$ \\
# \hline
# J0806+2006 & F160W & $0.41^{+0.02}_{-0.02}$ & $5.67^{+0.14}_{-0.15}$ & $0.90^{+0.01}_{-0.01}$ & $97.1^{+3.1}_{-3.3}$ \\
#  & F160W & $2.68^{+0.17}_{-0.19}$ & $2.46^{+0.19}_{-0.18}$ & $0.32^{+0.01}_{-0.01}$ & $35.2^{+1.3}_{-1.2}$ \\
#  & F814W & $0.56^{+0.03}_{-0.03}$ & $4.30^{+0.13}_{-0.13}$ & $0.88^{+0.01}_{-0.01}$ & $71.3^{+2.7}_{-2.8}$ \\
#  & F475X & $0.17^{+0.02}_{-0.01}$ & $1.38^{+0.18}_{-0.15}$ & $0.58^{+0.04}_{-0.04}$ & $33.5^{+2.9}_{-3.2}$ \\
# \hline
# J1001+5027 & F160W (Lens) & $1.59^{+0.02}_{-0.02}$ & $4.91^{+0.05}_{-0.07}$ & $0.81^{+0.00}_{-0.00}$ & $96.5^{+0.6}_{-0.7}$ \\
#  & F160W (Perturber) & $0.12^{+0.00}_{-0.00}$ & $3.49^{+0.06}_{-0.06}$ & $0.42^{+0.01}_{-0.01}$ & $94.5^{+0.4}_{-0.4}$ \\
#  & F814W (Lens) & $2.26^{+0.05}_{-0.05}$ & $5.67^{+0.05}_{-0.05}$ & $0.76^{+0.01}_{-0.01}$ & $109.4^{+1.1}_{-1.1}$ \\
#  & F814W (Perturber) & $0.45^{+0.02}_{-0.02}$ & $5.45^{+0.06}_{-0.07}$ & $0.53^{+0.01}_{-0.01}$ & $92.5^{+0.7}_{-0.7}$ \\
#  & F475X (Lens) & $3.09^{+0.06}_{-0.09}$ & $5.95^{+0.03}_{-0.04}$ & $0.60^{+0.02}_{-0.01}$ & $103.6^{+1.1}_{-1.5}$ \\
#  & F475X (Perturber) & $0.18^{+0.01}_{-0.01}$ & $3.27^{+0.06}_{-0.10}$ & $0.62^{+0.02}_{-0.01}$ & $89.5^{+1.3}_{-1.2}$ \\
# \hline
# J1442+4055 & F160W & $0.02^{+0.01}_{-0.01}$ & $5.91^{+0.05}_{-0.07}$ & $0.72^{+0.02}_{-0.02}$ & $25.8^{+1.9}_{-2.2}$ \\
#  & F160W & $0.44^{+0.01}_{-0.01}$ & $1.36^{+0.05}_{-0.04}$ & $0.73^{+0.01}_{-0.01}$ & $59.5^{+0.7}_{-0.7}$ \\
#  & F814W & $0.86^{+0.02}_{-0.02}$ & $5.89^{+0.07}_{-0.07}$ & $0.83^{+0.00}_{-0.00}$ & $49.9^{+0.8}_{-0.9}$ \\
#  & F475X & $1.11^{+0.04}_{-0.05}$ & $5.96^{+0.03}_{-0.04}$ & $0.91^{+0.01}_{-0.01}$ & $20.9^{+5.4}_{-5.7}$ \\
# \hline
# J1515+1511 & F160W & $0.39^{+0.01}_{-0.01}$ & $0.64^{+0.03}_{-0.03}$ & $0.15^{+0.00}_{-0.00}$ & $73.4^{+0.1}_{-0.1}$ \\
#  & F160W & $0.23^{+0.02}_{-0.02}$ & $3.30^{+0.25}_{-0.22}$ & $0.46^{+0.03}_{-0.03}$ & $69.2^{+1.4}_{-1.6}$ \\
#  & F814W & $0.42^{+0.02}_{-0.02}$ & $1.76^{+0.12}_{-0.11}$ & $0.16^{+0.01}_{-0.01}$ & $72.6^{+0.3}_{-0.3}$ \\
#  & F475X & $4.92^{+0.11}_{-0.13}$ & $1.38^{+0.15}_{-0.16}$ & $0.17^{+0.03}_{-0.03}$ & $49.8^{+2.5}_{-2.2}$ \\
# \hline
# J1620+1203 & F160W & $0.19^{+0.01}_{-0.01}$ & $2.02^{+0.07}_{-0.07}$ & $0.61^{+0.01}_{-0.02}$ & $49.4^{+0.8}_{-0.8}$ \\
#  & F160W & $2.64^{+0.06}_{-0.06}$ & $4.66^{+0.11}_{-0.10}$ & $0.80^{+0.00}_{-0.00}$ & $66.4^{+0.3}_{-0.3}$ \\
#  & F814W & $2.17^{+0.07}_{-0.07}$ & $5.46^{+0.06}_{-0.06}$ & $0.78^{+0.00}_{-0.00}$ & $66.1^{+0.6}_{-0.6}$ \\
#  & F475X & $2.14^{+0.13}_{-0.09}$ & $4.68^{+0.08}_{-0.05}$ & $0.71^{+0.01}_{-0.01}$ & $63.2^{+1.7}_{-1.6}$ \\
# \hline
# J2325-5229 & F160W & $0.04^{+0.01}_{-0.01}$ & $0.55^{+0.10}_{-0.07}$ & $0.61^{+0.02}_{-0.02}$ & $97.6^{+2.2}_{-1.6}$ \\
#  & F160W & $0.76^{+0.02}_{-0.02}$ & $2.75^{+0.05}_{-0.06}$ & $0.81^{+0.00}_{-0.00}$ & $144.9^{+0.3}_{-0.3}$ \\
#  & F814W & $3.03^{+0.19}_{-0.10}$ & $5.75^{+0.12}_{-0.07}$ & $0.83^{+0.00}_{-0.01}$ & $141.2^{+0.9}_{-0.9}$ \\
#  & F475X & $0.85^{+0.24}_{-0.09}$ & $3.49^{+0.68}_{-0.23}$ & $0.89^{+0.02}_{-0.02}$ & $119.4^{+4.6}_{-4.3}$ \\
# \hline
# \end{tabular*}

# %% [markdown]
# # Source Light

# %%
import pickle
import numpy as np

names = ['J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027', 'J1442+4055', 'J1515+1511', 'J1620+1203', 'J2325-5229']

# LaTeX header
print("\\begin{table}[htb]")
print("\\centering")
print("\\caption{F160W best-fit source light model parameters}")
print("\\label{tab:source_light_params_f814w}")
print("\\begin{tabular}lcccc}")
print("\\hline")
print("Lens System & $R_{\\text{S\\'ersic}}$ [arcsec] & $n_{\\text{S\\'ersic}}$ & $q$ \\\\")
print("\\hline")

def get_median_and_uncertainties_with_floor(
    samples,
    frac_floor=0.02,
    abs_floor=0.005  # arcsec
):
    """Compute uncertainties with a 2% floor, used in
    Sersic radius computation."""
    median = np.percentile(samples, 50)

    lo_stat = median - np.percentile(samples, 16)
    up_stat = np.percentile(samples, 84) - median

    # Systematic floor: relative OR absolute, whichever is larger
    floor = max(frac_floor * median, abs_floor)

    lo = np.sqrt(lo_stat**2 + floor**2)
    up = np.sqrt(up_stat**2 + floor**2)

    return median, lo, up

for i, name in enumerate(names):
    filename = f"../joint_modeling/{name}/{name}_joint.pkl"
    with open(filename, "rb") as f:
        loaded_data = pickle.load(f)

    chain_list = loaded_data.get('chain_list')
    sampler_type, samples_mcmc, param_mcmc, dist_mcmc = chain_list[3]

    param_names = ['R_sersic_source_light0', 'n_sersic_source_light0', 'e1_source_light0', 'e2_source_light0']
    indices = [param_mcmc.index(p) for p in param_names]

    r_chain = samples_mcmc[:, indices[0]]
    n_chain = samples_mcmc[:, indices[1]]
    e1_chain = samples_mcmc[:, indices[2]]
    e2_chain = samples_mcmc[:, indices[3]]

    e_chain = np.sqrt(e1_chain**2 + e2_chain**2)
    q_chain = (1 - e_chain) / (1 + e_chain)

    def get_median_and_uncertainties(samples):
        median = np.percentile(samples, 50)
        lower = median - np.percentile(samples, 16)
        upper = np.percentile(samples, 84) - median
        return median, lower, upper
    

    r_median, r_lower, r_upper = get_median_and_uncertainties_with_floor(r_chain)
    n_median, n_lower, n_upper = get_median_and_uncertainties(n_chain)
    q_median, q_lower, q_upper = get_median_and_uncertainties(q_chain)

    # Print table row
    print(f"{name} & "
          f"${r_median:.2f}^{{+{r_upper:.2f}}}_{{-{r_lower:.2f}}}$ & "
          f"${n_median:.2f}^{{+{n_upper:.2f}}}_{{-{n_lower:.2f}}}$ & "
          f"${q_median:.2f}^{{+{q_upper:.2f}}}_{{-{q_lower:.2f}}}$ & \\\\")

print("\\hline")
print("\\end{tabular}")
print("\\end{table}")
# Out:
# \begin{table}[htb]
# \centering
# \caption{F160W best-fit source light model parameters}
# \label{tab:source_light_params_f814w}
# \begin{tabular}lcccc}
# \hline
# Lens System & $R_{\text{S\'ersic}}$ [arcsec] & $n_{\text{S\'ersic}}$ & $q$ \\
# \hline
# J0407-5006 & $0.50^{+0.02}_{-0.02}$ & $2.38^{+0.14}_{-0.10}$ & $0.71^{+0.01}_{-0.02}$ & \\
# J0602-4335 & $0.25^{+0.03}_{-0.03}$ & $3.96^{+0.02}_{-0.03}$ & $0.33^{+0.00}_{-0.00}$ & \\
# J0806+2006 & $0.64^{+0.02}_{-0.02}$ & $0.53^{+0.03}_{-0.02}$ & $0.85^{+0.03}_{-0.03}$ & \\
# J1001+5027 & $0.41^{+0.01}_{-0.01}$ & $0.52^{+0.01}_{-0.01}$ & $0.71^{+0.01}_{-0.01}$ & \\
# J1442+4055 & $0.31^{+0.01}_{-0.01}$ & $0.51^{+0.02}_{-0.01}$ & $0.69^{+0.01}_{-0.01}$ & \\
# J1515+1511 & $0.30^{+0.02}_{-0.02}$ & $1.57^{+0.16}_{-0.14}$ & $0.40^{+0.02}_{-0.02}$ & \\
# J1620+1203 & $0.31^{+0.01}_{-0.01}$ & $1.76^{+0.09}_{-0.10}$ & $0.84^{+0.02}_{-0.02}$ & \\
# J2325-5229 & $1.25^{+0.04}_{-0.04}$ & $0.58^{+0.04}_{-0.04}$ & $0.80^{+0.02}_{-0.05}$ & \\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# # Mass Components, Fermat Potentials, and Time Delays

# %%
import pickle
import h5py
import numpy as np
import os
from lenstronomy.Util.param_util import ellipticity2phi_q
from lenstronomy.Util.param_util import shear_cartesian2polar

names = ['J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027', 'J1442+4055',
         'J1515+1511', 'J1620+1203', 'J2325-5229']

z_l = [0.50, 0.50, 0.573, 0.415, 0.284, 0.742, 0.398, 0.4]
z_s = [1.515, 2.92, 1.54, 1.838, 2.593, 2.049, 1.158, 2.739]

def get_median_and_uncertainties(samples):
    median = np.percentile(samples, 50)
    lower = median - np.percentile(samples, 16)
    upper = np.percentile(samples, 84) - median
    return median, lower, upper

def get_median_and_uncertainties_with_floor(
    samples,
    frac_floor=0.02,
    abs_floor=0.005  # arcsec
):
    """Compute uncertainties with a 2% floor"""
    median = np.percentile(samples, 50)

    lo_stat = median - np.percentile(samples, 16)
    up_stat = np.percentile(samples, 84) - median

    # Systematic floor: relative OR absolute, whichever is larger
    floor = max(frac_floor * median, abs_floor)

    lo = np.sqrt(lo_stat**2 + floor**2)
    up = np.sqrt(up_stat**2 + floor**2)

    return median, lo, up

def summarize_chain(chain, fmt=".2f", uncertainty_type='statistical'):
    if uncertainty_type=='statistical':
        med, lo, up = get_median_and_uncertainties(chain)
    elif uncertainty_type=='floor':
        med, lo, up = get_median_and_uncertainties_with_floor(chain)

    return f"${med:{fmt}}^{{+{up:{fmt}}}}_{{-{lo:{fmt}}}}$"

# Combined LaTeX Table 
print("\\begin{table*}[htb]")
print("\\centering")
print("\\caption{Lens model and cosmological parameters for each doubly imaged quasar system.}")
print("\\label{tab:joint_results}")
print("\\begin{tabular*}{\\textwidth}{@{\\extracolsep{\\fill}}lcccccccccc}")
print("\\hline")
print("Lens System & $\\theta_E$ [arcsec] & $q_{\\text{mass}}$ & "
      "$\\phi_{\\text{mass}}$ [deg] & $\\gamma$ & $z_l$ & $z_s$ & "
      "$\\Delta \\Phi_{AB}$ [arcsec$^2$] & $\\Delta t_{AB}$ [days] \\\\")
print("\\hline")

for i, name in enumerate(names):
    # Defaults
    theta_E = q_mass = phi_mass = gamma = "--"
    dphi_fmt = dt_fmt = "--"

    # Load lens model results 
    pkl_file = f"../joint_modeling/{name}/{name}_joint.pkl"
    if os.path.exists(pkl_file):
        try:
            with open(pkl_file, "rb") as f:
                loaded_data = pickle.load(f)

            chain_list = loaded_data.get('chain_list')
            sampler_type, samples_mcmc, param_mcmc, dist_mcmc = chain_list[3]

            # Handle J1001+5027 separately
            if name == "J1001+5027":
                # Use main lens (lens0)
                param_names_mass = ['theta_E_lens0', 'e1_lens0', 'e2_lens0', 'gamma1_lens2', 'gamma2_lens2']
            else:
                param_names_mass = ['theta_E_lens0', 'e1_lens0', 'e2_lens0', 'gamma1_lens1', 'gamma2_lens1']

            indices = [param_mcmc.index(p) for p in param_names_mass]

            theta_E_chain = samples_mcmc[:, indices[0]]
            e1_chain = samples_mcmc[:, indices[1]]
            e2_chain = samples_mcmc[:, indices[2]]
            gamma1_chain = samples_mcmc[:, indices[3]]
            gamma2_chain = samples_mcmc[:, indices[4]]

            e_chain = np.sqrt(e1_chain**2 + e2_chain**2)
            q_mass_chain = (1 - e_chain) / (1 + e_chain)
            phi_mass_chain = 0.5 * np.arctan2(e2_chain, e1_chain) * 180 / np.pi

            phi_mass_chain, q_mass_chain = ellipticity2phi_q(e1_chain, e2_chain)
            phi_mass_chain = (phi_mass_chain * 180/np.pi) % 180

            phi_ext_chain, gamma_chain = shear_cartesian2polar(gamma1_chain, gamma2_chain)
            phi_ext_chain = (phi_ext_chain * 180/np.pi) % 180

            theta_E = summarize_chain(theta_E_chain, fmt=".3f")
            q_mass = summarize_chain(q_mass_chain)
            phi_mass = summarize_chain(phi_mass_chain, fmt=".1f")
            gamma = summarize_chain(gamma_chain, uncertainty_type='floor') # use 2% systematic floor

        except Exception:
            pass

    # Load cosmological results
    h5_file = f"../joint_modeling/{name}/{name}_cosmo.hdf5"
    if os.path.exists(h5_file):
        try:
            with h5py.File(h5_file, "r") as f:
                kwargs = {key: f[key][()] for key in f}

            dphi_chain = kwargs['dphi_list']
            dt_chain = kwargs['dt_list']

            dphi_median, dphi_lower, dphi_upper = get_median_and_uncertainties(dphi_chain)
            dt_median, dt_lower, dt_upper = get_median_and_uncertainties(dt_chain)

            dphi_fmt = f"${dphi_median:.3f}^{{+{dphi_upper:.3f}}}_{{-{dphi_lower:.3f}}}$"
            dt_fmt = f"${dt_median:.1f}^{{+{dt_upper:.1f}}}_{{-{dt_lower:.1f}}}$"
        except Exception:
            pass

    # Combine everything into one row
    z_l_fmt = f"${z_l[i]}$"
    z_s_fmt = f"${z_s[i]}$"

    print(f"{name} & {theta_E} & {q_mass} & {phi_mass} & "
          f"{gamma} & {z_l_fmt} & {z_s_fmt} & {dphi_fmt} & {dt_fmt} \\\\")

print("\\hline")
print("\\end{tabular*}")
print("\\end{table*}")
# Out:
# \begin{table*}[htb]
# \centering
# \caption{Lens model and cosmological parameters for each doubly imaged quasar system.}
# \label{tab:joint_results}
# \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}lcccccccccc}
# \hline
# Lens System & $\theta_E$ [arcsec] & $q_{\text{mass}}$ & $\phi_{\text{mass}}$ [deg] & $\gamma$ & $z_l$ & $z_s$ & $\Delta \Phi_{AB}$ [arcsec$^2$] & $\Delta t_{AB}$ [days] \\
# \hline
# J0407-5006 & $0.837^{+0.008}_{-0.006}$ & $0.71^{+0.01}_{-0.02}$ & $27.6^{+7.2}_{-4.4}$ & $0.08^{+0.01}_{-0.01}$ & $0.5$ & $1.515$ & $0.982^{+0.013}_{-0.022}$ & $91.2^{+1.2}_{-2.0}$ \\
# J0602-4335 & $0.899^{+0.002}_{-0.002}$ & $0.62^{+0.01}_{-0.01}$ & $130.7^{+0.3}_{-0.3}$ & $0.06^{+0.01}_{-0.01}$ & $0.5$ & $2.92$ & $-0.539^{+0.001}_{-0.001}$ & $-40.8^{+0.1}_{-0.1}$ \\
# J0806+2006 & $0.677^{+0.008}_{-0.007}$ & $0.86^{+0.02}_{-0.03}$ & $125.7^{+8.0}_{-12.3}$ & $0.11^{+0.01}_{-0.01}$ & $0.573$ & $1.54$ & $-0.384^{+0.007}_{-0.006}$ & $-43.8^{+0.7}_{-0.7}$ \\
# J1001+5027 & $1.241^{+0.009}_{-0.008}$ & $0.88^{+0.01}_{-0.02}$ & $164.5^{+3.0}_{-3.3}$ & $0.07^{+0.01}_{-0.01}$ & $0.415$ & $1.838$ & $11.667^{+0.078}_{-0.089}$ & $775.8^{+5.2}_{-5.9}$ \\
# J1442+4055 & $1.055^{+0.003}_{-0.003}$ & $0.83^{+0.01}_{-0.01}$ & $104.1^{+2.2}_{-2.0}$ & $0.06^{+0.01}_{-0.01}$ & $0.284$ & $2.593$ & $-0.599^{+0.003}_{-0.003}$ & $-23.5^{+0.1}_{-0.1}$ \\
# J1515+1511 & $0.921^{+0.005}_{-0.010}$ & $0.54^{+0.03}_{-0.03}$ & $58.3^{+1.3}_{-1.1}$ & $0.03^{+0.01}_{-0.01}$ & $0.742$ & $2.049$ & $-0.842^{+0.028}_{-0.030}$ & $-123.8^{+4.1}_{-4.5}$ \\
# J1620+1203 & $1.408^{+0.007}_{-0.007}$ & $0.73^{+0.01}_{-0.01}$ & $62.6^{+1.3}_{-1.3}$ & $0.06^{+0.01}_{-0.01}$ & $0.398$ & $1.158$ & $2.384^{+0.008}_{-0.008}$ & $178.0^{+0.6}_{-0.6}$ \\
# J2325-5229 & $1.454^{+0.003}_{-0.005}$ & $0.79^{+0.06}_{-0.02}$ & $174.9^{+1.7}_{-4.1}$ & $0.02^{+0.01}_{-0.01}$ & $0.4$ & $2.739$ & $-0.789^{+0.034}_{-0.013}$ & $-46.0^{+2.0}_{-0.7}$ \\
# \hline
# \end{tabular*}
# \end{table*}

# %% [markdown]
# # Conjugate Point Comparison

# %%
import pickle
import h5py
import numpy as np
import os
from lenstronomy.Util import param_util


names = ['J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027', 'J1442+4055',
         'J1515+1511', 'J1620+1203', 'J2325-5229']

def get_median_and_uncertainties(samples):
    median = np.percentile(samples, 50)
    lower = median - np.percentile(samples, 16)
    upper = np.percentile(samples, 84) - median
    return median, lower, upper

def load_model_chains(name, model_type='joint'):
    """
    Load lens model chains for either joint (full) or conjugate modeling.
    Returns the actual chains, not formatted strings.
    model_type: 'joint' or 'conjugate'
    """
    theta_E_chain = q_mass_chain = phi_mass_chain = gamma_chain = None
    dphi_chain = dt_chain = None
    
    # Set directory and file paths based on model type
    if model_type == 'joint':
        base_dir = "../joint_modeling"
        pkl_suffix = "_joint.pkl"
        h5_suffix = "_cosmo.hdf5"
    else:  # conjugate
        base_dir = "../conjugate_point"
        pkl_suffix = "_conjugate.pkl"
        h5_suffix = "_cosmo_conjugate.hdf5"
    
    # Load lens model results
    pkl_file = f"{base_dir}/{name}/{name}{pkl_suffix}"
    if os.path.exists(pkl_file):
            with open(pkl_file, "rb") as f:
                loaded_data = pickle.load(f)

            if model_type == 'joint':
                chain_list = loaded_data.get('chain_list')
                sampler_type, samples_mcmc, param_mcmc, dist_mcmc = chain_list[3]
            else:  # conjugate
                samples_mcmc = loaded_data.get('samples_raw')
                param_mcmc = loaded_data.get('param_list')

            # Handle J1001+5027 separately
            if name == "J1001+5027":
                param_names_mass = ['theta_E_lens0', 'e1_lens0', 'e2_lens0', 'gamma1_lens2', 'gamma2_lens2']
            else:
                param_names_mass = ['theta_E_lens0', 'e1_lens0', 'e2_lens0', 'gamma1_lens1', 'gamma2_lens1']

            indices = [param_mcmc.index(p) for p in param_names_mass]

            theta_E_chain = samples_mcmc[:, indices[0]]
            e1_chain = samples_mcmc[:, indices[1]]
            e2_chain = samples_mcmc[:, indices[2]]
            gamma1_chain = samples_mcmc[:, indices[3]]
            gamma2_chain = samples_mcmc[:, indices[4]]

            phi_mass_chain, q_mass_chain = param_util.ellipticity2phi_q(e1_chain, e2_chain)
            phi_mass_chain = (phi_mass_chain * 180/np.pi) % 180
            
            phi_ext_chain, gamma_chain = param_util.shear_cartesian2polar(gamma1_chain, gamma2_chain)
            phi_ext_chain = (phi_ext_chain * 180/np.pi) % 180

    # Load cosmological results
    h5_file = f"{base_dir}/{name}/{name}{h5_suffix}"
    if os.path.exists(h5_file):
            with h5py.File(h5_file, "r") as f:
                kwargs = {key: f[key][()] for key in f}

            dt_chain = kwargs['dt_list']
    
    return theta_E_chain, q_mass_chain, phi_mass_chain, gamma_chain, phi_ext_chain, dt_chain

def compute_fractional_difference(chain_cp, chain_full):
    """
    Compute fractional difference: (Conjugate - Full) / Full * 100%
    Returns formatted string with median and uncertainties
    """
    if chain_cp is None or chain_full is None:
        return "--"
    
    # Make sure chains are same length
    n_samples = min(len(chain_cp), len(chain_full))
    frac_diff_chain = (chain_cp[:n_samples] - chain_full[:n_samples]) / chain_full[:n_samples] * 100
    
    median, lower, upper = get_median_and_uncertainties(frac_diff_chain)
    
    return f"${median:.1f}^{{+{upper:.1f}}}_{{-{lower:.1f}}}$"

print("\\begin{table*}[htb]")
print("\\centering")
print("\\caption{Fractional differences in lens model and cosmological parameters between conjugate point modeling and full image modeling: "
      "$(\\text{Conjugate} - \\text{Full})/\\text{Full} \\times 100\\%$.}")
print("\\label{tab:model_frac_differences}")
print("\\begin{tabular}{lcccccc}")
print("\\hline")
print("Lens System & $\\Delta\\theta_E/\\theta_E$ & $\\Delta q/q$ & $\\Delta\\phi/\\phi$ & "
      "$\\Delta\\gamma/\\gamma$ & $\\Delta\\phi/\\phi$ & $\\Delta(\\Delta t)/\\Delta t$ \\\\")
print(" & [\\%] & [\\%] & [\\%] & [\\%] & [\\%] & [\\%] \\\\")
print("\\hline")

for i, name in enumerate(names):
    # Load chains
    theta_E_full, q_mass_full, phi_mass_full, gamma_full, dphi_gamma_full, dt_full = load_model_chains(name, 'joint')
    theta_E_cp, q_mass_cp, phi_mass_cp, gamma_cp, dphi_gamma_cp, dt_cp = load_model_chains(name, 'conjugate')
    
    # Compute fractional differences
    frac_theta_E = compute_fractional_difference(theta_E_cp, theta_E_full)
    frac_q_mass = compute_fractional_difference(q_mass_cp, q_mass_full)
    frac_phi_mass = compute_fractional_difference(phi_mass_cp, phi_mass_full)
    frac_gamma = compute_fractional_difference(gamma_cp, gamma_full)
    frac_phi_gamma = compute_fractional_difference(dphi_gamma_cp, dphi_gamma_full)
    frac_dt = compute_fractional_difference(dt_cp, dt_full)
    
    print(f"{name} & {frac_theta_E} & {frac_q_mass} & {frac_phi_mass} & "
          f"{frac_phi_gamma} & {frac_gamma} & {frac_dt} \\\\")

print("\\hline")
print("\\end{tabular}")
print("\\end{table*}")
# Out:
# \begin{table*}[htb]
# \centering
# \caption{Fractional differences in lens model and cosmological parameters between conjugate point modeling and full image modeling: $(\text{Conjugate} - \text{Full})/\text{Full} \times 100\%$.}
# \label{tab:model_frac_differences}
# \begin{tabular}{lcccccc}
# \hline
# Lens System & $\Delta\theta_E/\theta_E$ & $\Delta q/q$ & $\Delta\phi/\phi$ & $\Delta\gamma/\gamma$ & $\Delta\phi/\phi$ & $\Delta(\Delta t)/\Delta t$ \\
#  & [\%] & [\%] & [\%] & [\%] & [\%] & [\%] \\
# \hline
# J0407-5006 & $-2.0^{+6.5}_{-6.0}$ & $2.7^{+18.7}_{-18.5}$ & $487.4^{+116.4}_{-401.1}$ & $155.0^{+160.9}_{-116.7}$ & $8.3^{+37.1}_{-48.7}$ & $3.0^{+7.1}_{-7.2}$ \\
# J0602-4335 & $1.8^{+5.5}_{-5.3}$ & $28.5^{+14.7}_{-12.1}$ & $-44.8^{+52.6}_{-31.6}$ & $-34.8^{+60.5}_{-34.9}$ & $31.1^{+44.5}_{-58.9}$ & $-5.5^{+7.6}_{-6.2}$ \\
# J0806+2006 & $7.8^{+6.7}_{-6.4}$ & $-6.5^{+10.0}_{-9.6}$ & $-39.1^{+63.7}_{-41.3}$ & $-25.1^{+38.5}_{-53.9}$ & $-27.0^{+26.0}_{-31.8}$ & $9.4^{+8.0}_{-7.7}$ \\
# J1001+5027 & $8.5^{+7.2}_{-8.5}$ & $-33.0^{+10.1}_{-10.4}$ & $-72.3^{+5.3}_{-3.5}$ & $1130.7^{+362.8}_{-479.4}$ & $29.3^{+38.8}_{-57.3}$ & $-117.0^{+2.1}_{-1.9}$ \\
# J1442+4055 & $1.7^{+4.5}_{-4.6}$ & $-7.6^{+11.4}_{-10.6}$ & $50.3^{+14.2}_{-136.9}$ & $16.1^{+22.8}_{-93.0}$ & $30.5^{+48.4}_{-59.2}$ & $-3.5^{+6.8}_{-5.6}$ \\
# J1515+1511 & $6.7^{+6.3}_{-5.9}$ & $49.9^{+19.6}_{-19.4}$ & $3.5^{+120.4}_{-55.7}$ & $-23.1^{+53.1}_{-48.1}$ & $208.3^{+135.8}_{-150.2}$ & $0.2^{+7.7}_{-7.3}$ \\
# J1620+1203 & $-1.6^{+5.9}_{-6.1}$ & $11.7^{+14.0}_{-18.0}$ & $96.1^{+30.7}_{-108.9}$ & $242.9^{+138.0}_{-302.3}$ & $58.7^{+43.4}_{-60.8}$ & $5.0^{+7.5}_{-7.8}$ \\
# J2325-5229 & $-1.3^{+5.3}_{-5.0}$ & $9.7^{+9.2}_{-10.7}$ & $-79.1^{+65.6}_{-13.1}$ & $-52.4^{+19.4}_{-21.4}$ & $231.7^{+137.0}_{-145.7}$ & $-9.2^{+6.9}_{-8.2}$ \\
# \hline
# \end{tabular}
# \end{table*}

# %% [markdown]
# # Compute likelihood-ratio for source vs. no source models

# %%
import pickle
import numpy as np
import h5py
import os
from astropy.io import fits
from lenstronomy.Workflow.fitting_sequence import FittingSequence

# Helper functions
def get_back_rms(system, filter):
    """Get background RMS from the cutout FITS file header"""
    if filter == 'F160W':
        path_to_fits = f'../cutout_data/{system}/{filter}/{system}_{filter}_cutout.fits'
    else:
        path_to_fits = f'../joint_modeling/{system}/{system}_{filter}_cutout.fits'

    with fits.open(path_to_fits) as hdul:
        if 'BACK_RMS' in hdul[0].header:
            return hdul[0].header['BACK_RMS']

def summarize_flux_from_sigma(flux, sigma, back_rms=None):
    """
    Given flux and asymmetric sigma = [upper, lower],
    return median, -err, +err, S/N.
    If back_rms is provided, add it in quadrature to the uncertainty.
    """
    sigma_up, sigma_lo = sigma
    
    # Add background RMS noise in quadrature if available
    if back_rms is not None:
        sigma_up = np.sqrt(sigma_up**2 + back_rms**2)
        sigma_lo = np.sqrt(sigma_lo**2 + back_rms**2)
    
    sigma_mean = 0.5 * (sigma_up + sigma_lo)
    snr = flux / sigma_mean if sigma_mean > 0 else 0.0
    return flux, sigma_lo, sigma_up, snr

# Systems and filters
systems = [
    'J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027',
    'J1442+4055', 'J1515+1511', 'J1620+1203', 'J2325-5229'
]
filters = ["F160W", "F814W", "F475X"]

# Main loop
for name in systems:
    fn_ns = f'../no_source/{name}/{name}_joint.pkl'
    fn_s  = f'../joint_modeling/{name}/{name}_joint.pkl'
    fn_phot = f'../joint_modeling/{name}/{name}_photometry.hdf5'
    
    with open(fn_ns, 'rb') as f:
        data_ns = pickle.load(f)
    with open(fn_s, 'rb') as f:
        data_s = pickle.load(f)
    
    # No-source model
    fs_ns = FittingSequence(
        kwargs_data_joint=data_ns['kwargs_data_joint'],
        kwargs_model=data_ns['kwargs_model'],
        kwargs_constraints=data_ns['kwargs_constraints'],
        kwargs_likelihood=data_ns['kwargs_likelihood'],
        kwargs_params=data_ns['kwargs_params'],
        verbose=False
    )
    fs_ns.update_state(data_ns['kwargs_result'])
    logL_ns = fs_ns.best_fit_likelihood()
    BIC_ns = fs_ns.bic
    
    # Source model 
    fs_s = FittingSequence(
        kwargs_data_joint=data_s['kwargs_data_joint'],
        kwargs_model=data_s['kwargs_model'],
        kwargs_constraints=data_s['kwargs_constraints'],
        kwargs_likelihood=data_s['kwargs_likelihood'],
        kwargs_params=data_s['kwargs_params'],
        verbose=False
    )
    fs_s.update_state(data_s['kwargs_result'])
    logL_s = fs_s.best_fit_likelihood()
    BIC_s = fs_s.bic
    delta_bic = BIC_ns - BIC_s
    
    # Print diagnostics
    print(f"{name}")
    print(f"  logL (no source): {logL_ns:.2f}")
    print(f"  logL (source)   : {logL_s:.2f}")
    print(f"  ΔBIC            : {delta_bic:.1f}")
    
    # Host photometry
    
    with h5py.File(fn_phot, "r") as f:
        for filt in filters:
            
            g = f[filt]
            mag_key   = "host_lensed_mag"
            flux_key  = "host_lensed_flux"
            sigma_key = "host_lensed_flux_sigma"
            
            if mag_key not in g or np.isnan(g[mag_key][()]):
                print(f"    {filt}: host not detected (photometry)")
                continue
            
            flux = g[flux_key][()]
            sigma = g[sigma_key][()]
            
            # Get background RMS for this system/filter
            back_rms = get_back_rms(name, filt)
            
            # Calculate flux and SNR with background noise included
            med, lo, up, snr = summarize_flux_from_sigma(flux, sigma, back_rms)
            
            rms_str = f" (with bkg RMS)"
            print(
                f"    {filt} host: "
                f"{med:.3g} (+{up:.3g}/-{lo:.3g}), "
                f"S/N ≈ {snr:.1f}{rms_str}"
            )
    print()
# Out:
# /Users/rbrady0110/micromamba/envs/doubles/lib/python3.13/site-packages/lenstronomy/Data/psf.py:95: UserWarning: Input PSF model has at least one negative element, which is unphysical except for a PSF of an interferometric array.
#   warnings.warn(
# J0407-5006
#   logL (no source): -21896.58
#   logL (source)   : -15806.27
#   ΔBIC            : 12131.1
#     F160W host: 280 (+5.05/-5.65), S/N ≈ 52.4 (with bkg RMS)
#     F814W host: 27.4 (+0.903/-0.986), S/N ≈ 29.0 (with bkg RMS)
#     F475X host: 22.8 (+0.639/-0.527), S/N ≈ 39.1 (with bkg RMS)
#
# J0602-4335
#   logL (no source): -25659.13
#   logL (source)   : -23708.49
#   ΔBIC            : 3849.1
#     F160W host: 96.6 (+2/-1.54), S/N ≈ 54.6 (with bkg RMS)
#     F814W host: 1.64 (+0.317/-0.286), S/N ≈ 5.4 (with bkg RMS)
#     F475X host: 1.43 (+0.287/-0.276), S/N ≈ 5.1 (with bkg RMS)
#
# J0806+2006
#   logL (no source): -10236.20
#   logL (source)   : -9962.19
#   ΔBIC            : 497.1
#     F160W host: 86.5 (+5.79/-5.46), S/N ≈ 15.4 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X: host not detected (photometry)
#
# J1001+5027
#   logL (no source): -39318.75
#   logL (source)   : -29262.78
#   ΔBIC            : 20047.5
#     F160W host: 521 (+4.65/-4.25), S/N ≈ 117.1 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X host: 44.9 (+0.624/-0.695), S/N ≈ 68.0 (with bkg RMS)
#
# J1442+4055
#   logL (no source): -11513.98
#   logL (source)   : -10834.92
#   ΔBIC            : 1307.8
#     F160W host: 329 (+6.88/-7.82), S/N ≈ 44.8 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X host: 10.1 (+0.897/-0.857), S/N ≈ 11.5 (with bkg RMS)
#
# J1515+1511
#   logL (no source): -11314.99
#   logL (source)   : -10771.37
#   ΔBIC            : 1036.5
#     F160W host: 82.6 (+3.44/-3.83), S/N ≈ 22.7 (with bkg RMS)
#     F814W host: 5.37 (+0.482/-0.631), S/N ≈ 9.7 (with bkg RMS)
#     F475X host: 9.11 (+0.826/-0.719), S/N ≈ 11.8 (with bkg RMS)
#
# J1620+1203
#   logL (no source): -24288.70
#   logL (source)   : -16919.96
#   ΔBIC            : 14685.5
#     F160W host: 130 (+3.92/-3.98), S/N ≈ 32.9 (with bkg RMS)
#     F814W host: 8.84 (+0.356/-0.314), S/N ≈ 26.4 (with bkg RMS)
#     F475X host: 19 (+0.679/-0.751), S/N ≈ 26.6 (with bkg RMS)
#
# J2325-5229
#   logL (no source): -20147.12
#   logL (source)   : -15985.45
#   ΔBIC            : 8051.4
#     F160W host: 421 (+13.8/-12.2), S/N ≈ 32.3 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X: host not detected (photometry)
