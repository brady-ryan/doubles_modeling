# %% [markdown]
# # Astrometry

# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
from lenstronomy.Plots.model_plot import ModelPlot
import pickle 
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.io import fits

# define filters and system names
names = ['J0407-5006',
         'J0602-4335',
        'J0806+2006', 
         'J1001+5027',
         'J1442+4055', 
         'J1515+1511', 
         'J1620+1203', 
         'J2325-5229'
        ]

# table format:
# Lens System Name, RA_lens, Dec_lens, RA_im1, Dec_im1, Ra_im2, Dec_im2, Image Separation [arcsec]
print("\\begin{tabular}{lccccccc}")
print("\\hline")
print("Lens System & RA & DEC & RA$_{im1}$ & DEC$_{im1}$ & RA$_{im2}$ & DEC$_{im2}$ & Separation [arcsec]\\\\")
print("\\hline")

class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        # Handle missing LikelihoodAddition class
        if name == 'LikelihoodAddition':
            class LikelihoodAddition:
                pass
            return LikelihoodAddition
        return super().find_class(module, name)

for i, name in enumerate(names):
    filename = f"../joint_modeling/{name}/{name}_joint.pkl"

    with open(filename, "rb") as f:
        loaded_data = CustomUnpickler(f).load()

    kwargs_result = loaded_data["kwargs_result"]

    ra_lens = kwargs_result['kwargs_lens'][0]['center_x']
    dec_lens = kwargs_result['kwargs_lens'][0]['center_y']

    ra_im1 = kwargs_result['kwargs_ps'][0]['ra_image'][0] - ra_lens
    dec_im1 = kwargs_result['kwargs_ps'][0]['dec_image'][0] - dec_lens

    ra_im2 = kwargs_result['kwargs_ps'][0]['ra_image'][1] - ra_lens
    dec_im2 = kwargs_result['kwargs_ps'][0]['dec_image'][1] - dec_lens

    image_sep = np.sqrt((ra_im1 - ra_im2)**2 + (dec_im1 - dec_im2)**2)

    filename = f'../cutout_data/{name}/F814W/{name}_F814W_cutout.fits'
    hdul = fits.open(filename)
    header = hdul[0].header
    
    ra_deg = header['RA_TARG']
    dec_deg = header['DEC_TARG']
    
    coord = SkyCoord(ra=ra_deg*u.deg, dec=dec_deg*u.deg)
    
    # Keep RA and DEC to 5 significant digits
    RA = coord.ra.to_string(unit=u.hour, sep=':', precision=3)
    DEC = coord.dec.to_string(unit=u.deg, sep=':', precision=3)

    print(f"{name} & {RA} & {DEC} & {ra_im1:.3f} & {dec_im1:.3f} & {ra_im2:.3f} & {dec_im2:.3f} & {image_sep:.3f} \\\\")

print("\\hline")
print("\\end{tabular}")
# Out:
# \begin{tabular}{lccccccc}
# \hline
# Lens System & RA & DEC & RA$_{im1}$ & DEC$_{im1}$ & RA$_{im2}$ & DEC$_{im2}$ & Separation [arcsec]\\
# \hline
# J0407-5006 & 4:07:10.272 & -50:06:01.510 & -0.164 & -0.249 & 0.715 & 1.227 & 1.718 \\
# J0602-4335 & 6:02:16.100 & -43:35:40.200 & -0.757 & -0.934 & 0.410 & 0.471 & 1.826 \\
# J0806+2006 & 8:06:23.680 & 20:06:31.460 & -0.925 & 0.499 & 0.396 & -0.177 & 1.484 \\
# J1001+5027 & 10:01:28.500 & 50:27:57.420 & -2.043 & -1.118 & 0.443 & 0.437 & 2.932 \\
# J1442+4055 & 14:42:54.700 & 40:55:35.620 & -1.289 & 0.409 & 0.761 & -0.160 & 2.128 \\
# J1515+1511 & 15:15:38.540 & 15:11:35.120 & -1.376 & 0.863 & 0.295 & -0.252 & 2.009 \\
# J1620+1203 & 16:20:26.234 & 12:03:40.680 & -0.337 & -0.408 & 1.771 & 1.455 & 2.813 \\
# J2325-5229 & 23:25:41.210 & -52:29:15.000 & -0.488 & 1.651 & 0.918 & -0.794 & 2.820 \\
# \hline
# \end{tabular}

# %% [markdown]
# # Magnitude Table

# %%
import h5py
import numpy as np
import os

# Define system names
names = ['J0407-5006',
        'J0806+2006',
         'J0602-4335',
         'J1001+5027',
         'J1442+4055',
        'J1515+1511',
        'J1620+1203',
        'J2325-5229'
        ]

def flux_ratio_and_sigma(fA, fB, sigmaA, sigmaB):
    """Compute flux ratio fA/fB with asymmetric errors."""
    ratio = fA / fB
    sigmaA_upper, sigmaA_lower = sigmaA
    sigmaB_upper, sigmaB_lower = sigmaB
    sigmaR_upper = ratio * np.sqrt((sigmaA_upper / fA)**2 + (sigmaB_lower / fB)**2)
    sigmaR_lower = ratio * np.sqrt((sigmaA_lower / fA)**2 + (sigmaB_upper / fB)**2)
    return ratio, sigmaR_upper, sigmaR_lower

def format_quantity(val, upper, lower, decimals=2):
    return f"${val:.{decimals}f}^{{+{upper:.{decimals}f}}}_{{-{lower:.{decimals}f}}}$"

def mag_sigma(flux, sigma_flux, zp_err_mag=0.018):
    sigma_flux = np.asarray(sigma_flux)
    sigma_upper = sigma_flux[0]
    sigma_lower = sigma_flux[1]
    zp_flux_err = 0.921 * flux * zp_err_mag
    total_upper = np.sqrt(sigma_upper**2 + zp_flux_err**2)
    total_lower = np.sqrt(sigma_lower**2 + zp_flux_err**2)
    mag_err_upper = (2.5 / np.log(10)) * (total_upper / flux)
    mag_err_lower = (2.5 / np.log(10)) * (total_lower / flux)
    return mag_err_upper, mag_err_lower

def format_mag(mag, sigmas):
    return f"${mag:.2f}^{{+{sigmas[0]:.2f}}}_{{-{sigmas[1]:.2f}}}$"

# LaTeX header
print("\\begin{tabular*}{\\textwidth}{@{\\extracolsep{\\fill}}lccccccc}")
print("\\hline")
print("Lens System & Filter & Lens & Image A & Image B & Host (lensed) & Host (delensed) & $f_A/f_B$ \\\\")
print("\\hline")

# Loop over systems
for name in names:
    for filt in ["F160W", "F814W", "F475X"]:
        filename = f"../joint_modeling/{name}/{name}_photometry.hdf5"

        if not os.path.exists(filename):
            print(f"{name} & {filt} & -- & -- & -- & -- & -- & -- \\\\")
            continue

        with h5py.File(filename, "r") as f:
            if filt not in f:
                print(f"{name} & {filt} & -- & -- & -- & -- & -- & -- \\\\")
                continue
            g = f[filt]

            def get_component_row(label_prefix):
                if f"{label_prefix}_flux" not in g:
                    return "--"
                flux = g[f"{label_prefix}_flux"][()]
                flux_sigma = g[f"{label_prefix}_flux_sigma"][()]
                mag = g[f"{label_prefix}_mag"][()]
                return format_mag(mag, mag_sigma(flux, flux_sigma))

            fA = g["image1_flux"][()]
            fB = g["image2_flux"][()]
            sigmaA = g["image1_flux_sigma"][()]
            sigmaB = g["image2_flux_sigma"][()]
            magA = g["image1_mag"][()]
            magB = g["image2_mag"][()]
            magA_fmt = format_mag(magA, mag_sigma(fA, sigmaA))
            magB_fmt = format_mag(magB, mag_sigma(fB, sigmaB))
            ratio, r_up, r_low = flux_ratio_and_sigma(fA, fB, sigmaA, sigmaB)
            flux_ratio_fmt = format_quantity(ratio, r_up, r_low, decimals=2)

            # --- Hosts ---
            def get_host(label):
                """Return formatted host magnitude or N/A if NaN."""
                mag_key = f"host_{label}_mag"
                flux_key = f"host_{label}_flux"
                flux_sigma_key = f"host_{label}_flux_sigma"

                if mag_key not in g:
                    return "--"

                mag = g[mag_key][()]
                if np.isnan(mag):
                    return "N/A"

                flux = g[flux_key][()]
                flux_sigma = g[flux_sigma_key][()]
                return format_mag(mag, mag_sigma(flux, flux_sigma))

            host_lensed_fmt = get_host("lensed")
            host_intrinsic_fmt = get_host("intrinsic")

            lens_mag_fmt = get_component_row("lens")

            if filt == 'F160W':
                print(f"{name} & {filt} & {lens_mag_fmt} & {magA_fmt} & {magB_fmt} & {host_lensed_fmt} & {host_intrinsic_fmt} & {flux_ratio_fmt} \\\\")
            else:
                print(f" & {filt} & {lens_mag_fmt} & {magA_fmt} & {magB_fmt} & {host_lensed_fmt} & {host_intrinsic_fmt} & {flux_ratio_fmt} \\\\")


    print("\\hline")

print("\\end{tabular*}")
# Out:
# \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}lccccccc}
# \hline
# Lens System & Filter & Lens & Image A & Image B & Host (lensed) & Host (delensed) & $f_A/f_B$ \\
# \hline
# J0407-5006 & F160W & $18.11^{+0.02}_{-0.02}$ & $18.46^{+0.03}_{-0.03}$ & $17.63^{+0.03}_{-0.03}$ & $18.62^{+0.07}_{-0.07}$ & $19.86^{+0.11}_{-0.08}$ & $0.47^{+0.01}_{-0.01}$ \\
#  & F814W & $20.16^{+0.03}_{-0.04}$ & $19.31^{+0.02}_{-0.02}$ & $18.02^{+0.02}_{-0.02}$ & N/A & N/A & $0.30^{+0.00}_{-0.00}$ \\
#  & F475X & $22.44^{+0.17}_{-0.13}$ & $19.86^{+0.02}_{-0.02}$ & $18.67^{+0.02}_{-0.02}$ & $22.38^{+0.06}_{-0.07}$ & $23.62^{+0.09}_{-0.09}$ & $0.34^{+0.00}_{-0.00}$ \\
# \hline
# J0806+2006 & F160W & $18.42^{+0.03}_{-0.03}$ & $18.82^{+0.02}_{-0.02}$ & $19.73^{+0.02}_{-0.03}$ & $21.26^{+0.09}_{-0.08}$ & $22.99^{+0.27}_{-0.15}$ & $2.31^{+0.05}_{-0.04}$ \\
#  & F814W & $19.85^{+0.03}_{-0.03}$ & $19.22^{+0.02}_{-0.02}$ & $20.03^{+0.02}_{-0.02}$ & $23.03^{+0.11}_{-0.09}$ & $24.80^{+0.18}_{-0.15}$ & $2.10^{+0.01}_{-0.01}$ \\
#  & F475X & $22.94^{+0.04}_{-0.04}$ & $19.83^{+0.02}_{-0.02}$ & $20.54^{+0.02}_{-0.02}$ & $23.95^{+0.16}_{-0.16}$ & $25.69^{+0.26}_{-0.19}$ & $1.93^{+0.02}_{-0.01}$ \\
# \hline
# J0602-4335 & F160W & $17.33^{+0.02}_{-0.02}$ & $19.05^{+0.02}_{-0.02}$ & $19.26^{+0.02}_{-0.02}$ & $20.97^{+0.06}_{-0.05}$ & $22.93^{+0.06}_{-0.06}$ & $1.22^{+0.02}_{-0.02}$ \\
#  & F814W & $18.78^{+0.02}_{-0.02}$ & $20.47^{+0.02}_{-0.02}$ & $18.99^{+0.02}_{-0.02}$ & $22.84^{+0.06}_{-0.06}$ & $24.24^{+0.08}_{-0.08}$ & $0.26^{+0.00}_{-0.00}$ \\
#  & F475X & $21.21^{+0.03}_{-0.03}$ & $20.84^{+0.02}_{-0.02}$ & $19.39^{+0.02}_{-0.02}$ & N/A & N/A & $0.26^{+0.00}_{-0.00}$ \\
# \hline
# J2325-5229 & F160W & $17.73^{+0.02}_{-0.02}$ & $20.15^{+0.02}_{-0.02}$ & $20.47^{+0.02}_{-0.02}$ & $19.25^{+0.11}_{-0.09}$ & $20.62^{+0.18}_{-0.14}$ & $1.35^{+0.02}_{-0.01}$ \\
#  & F814W & $18.79^{+0.03}_{-0.03}$ & $20.61^{+0.02}_{-0.02}$ & $21.01^{+0.02}_{-0.02}$ & N/A & N/A & $1.46^{+0.01}_{-0.01}$ \\
#  & F475X & $20.83^{+0.03}_{-0.03}$ & $21.32^{+0.02}_{-0.02}$ & $21.95^{+0.02}_{-0.02}$ & N/A & N/A & $1.79^{+0.01}_{-0.01}$ \\
# \hline
# \end{tabular*}

# %% [markdown]
# # Lens Light Parameter Table

# %%
import pickle
import numpy as np
import os
import h5py
from lenstronomy.Util.param_util import ellipticity2phi_q


# Lens systems
names = [
    'J0407-5006',
    'J0602-4335',
    'J0806+2006',
    'J1001+5027',
    'J1442+4055',
    'J1515+1511',
    'J1620+1203',
    'J2325-5229'
]

class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if name == 'LikelihoodAddition':
            class LikelihoodAddition:
                pass
            return LikelihoodAddition
        return super().find_class(module, name)


# Statistics helpers
def get_median_and_uncertainties(samples):
    median = np.percentile(samples, 50)
    lower = median - np.percentile(samples, 16)
    upper = np.percentile(samples, 84) - median
    return median, lower, upper


def get_median_and_uncertainties_with_floor(
    samples,
    frac_floor=0.02,
    abs_floor=0.005
):
    median = np.percentile(samples, 50)

    lo_stat = median - np.percentile(samples, 16)
    up_stat = np.percentile(samples, 84) - median

    floor = max(frac_floor * median, abs_floor)

    lo = np.sqrt(lo_stat**2 + floor**2)
    up = np.sqrt(up_stat**2 + floor**2)

    return median, lo, up


def format_val(med, lo, up, fmt=".2f"):
    return f"${med:{fmt}}^{{+{up:{fmt}}}}_{{-{lo:{fmt}}}}$"


def summarize_chain(chain, fmt=".2f"):
    med, lo, up = get_median_and_uncertainties(chain)
    return format_val(med, lo, up, fmt)


def summarize_chain_with_floor(chain, fmt=".2f", frac_floor=0.02):
    med, lo, up = get_median_and_uncertainties_with_floor(chain, frac_floor)
    return format_val(med, lo, up, fmt)


# Extract Sérsic profile
def extract_profile(samples, param_names, param_mcmc):

    idx = [param_mcmc.index(p) for p in param_names]

    r_chain  = samples[:, idx[0]]
    n_chain  = samples[:, idx[1]]
    e1_chain = samples[:, idx[2]]
    e2_chain = samples[:, idx[3]]

    phi_chain, q_chain = ellipticity2phi_q(e1_chain, e2_chain)
    phi_chain = (phi_chain * 180 / np.pi) % 180

    return r_chain, n_chain, q_chain, phi_chain


# Filter maps
default_filter_map = {
    "F160W": [0, 1],
    "F814W": [2],
    "F475X": [3],
}

# J1001 has perturber in modeling,
# but we only print the LENS component
j1001_filter_map = {
    "F160W": [0],
    "F814W": [2],
    "F475X": [4],
}

# J0602 special indexing
j0602_filter_map = {
    "F160W": [0, 1],
    "F814W": [2, 3],
    "F475X": [4, 5],
}

print("\\begin{tabular*}{\\textwidth}{@{\\extracolsep{\\fill}}lccccc}")
print("\\hline")
print(
    "Lens System & Filter & $R_{\\text{S\\'ersic}}$ [arcsec] & "
    "$n_{\\text{S\\'ersic}}$ & $q$ & $\\phi$ [deg] \\\\"
)
print("\\hline")


for name in names:

    # Load MCMC chains
    filename = f"../joint_modeling/{name}/{name}_joint.pkl"

    with open(filename, "rb") as f:
        loaded_data = CustomUnpickler(f).load()

    sampler_type, samples, param_mcmc, dist_mcmc = loaded_data["chain_list"][-1]

    # Load composite photometry
    composite = {}
    hdf5_file = f"../joint_modeling/{name}/{name}_photometry.hdf5"

    if os.path.exists(hdf5_file):
        with h5py.File(hdf5_file, "r") as f:
            for filt in ["F160W", "F814W", "F475X"]:
                if filt not in f:
                    continue

                composite[filt] = {
                    "r_eff": f[filt]["ellipticity"]["r_eff_samples"][()],
                    "q":     f[filt]["ellipticity"]["q_samples"][()],
                    "phi":   f[filt]["ellipticity"]["phi_samples"][()]
                }

    # Select filter map
    if name == "J1001+5027":
        filter_map = j1001_filter_map
    elif name == "J0602-4335":  
        filter_map = j0602_filter_map
    else:
        filter_map = default_filter_map

    row_started = False

    for filt in ["F160W", "F814W", "F475X"]:

        prof_indices = filter_map.get(filt, [])
        if not prof_indices:
            continue

        for prof_idx in prof_indices:

            try:
                param_names = [
                    f"R_sersic_lens_light{prof_idx}",
                    f"n_sersic_lens_light{prof_idx}",
                    f"e1_lens_light{prof_idx}",
                    f"e2_lens_light{prof_idx}"
                ]

                r, n, q, phi = extract_profile(
                    samples, param_names, param_mcmc
                )

                r_str   = summarize_chain_with_floor(r)
                n_str   = summarize_chain(n)
                q_str   = summarize_chain(q, fmt=".3f")
                phi_str = summarize_chain(phi, fmt=".1f")

            except Exception:
                r_str = n_str = q_str = phi_str = "--"

            if not row_started:
                print(f"{name} & {filt} & {r_str} & {n_str} & {q_str} & {phi_str} \\\\")
                row_started = True
            else:
                print(f" & {filt} & {r_str} & {n_str} & {q_str} & {phi_str} \\\\")

        # Composite logic

        if name == "J1001+5027":
            continue

        if name == "J0602-4335":
            if filt in composite:

                r_eff_str = summarize_chain_with_floor(
                    composite[filt]["r_eff"]
                )
                q_L_str = summarize_chain(
                    composite[filt]["q"], fmt=".3f"
                )
                phi_L_str = summarize_chain(
                    composite[filt]["phi"], fmt=".1f"
                )

                print(
                    f" & {filt} Composite & {r_eff_str} & $--$ & "
                    f"{q_L_str} & {phi_L_str} \\\\"
                )

        else:
            if filt == "F160W" and "F160W" in composite:

                r_eff_str = summarize_chain_with_floor(
                    composite["F160W"]["r_eff"]
                )
                q_L_str = summarize_chain(
                    composite["F160W"]["q"], fmt=".3f"
                )
                phi_L_str = summarize_chain(
                    composite["F160W"]["phi"], fmt=".1f"
                )

                print(
                    f" & F160W Composite & {r_eff_str} & $--$ & "
                    f"{q_L_str} & {phi_L_str} \\\\"
                )


    print("\\hline")


print("\\end{tabular*}")
# Out:
# \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}
#  & F160W & $2.62^{+0.21}_{-0.17}$ & $5.24^{+0.40}_{-0.33}$ & $0.796^{+0.002}_{-0.002}$ & $65.9^{+0.3}_{-0.3}$ \\
#  & F160W Composite & $0.67^{+0.01}_{-0.01}$ & $--$ & $0.773^{+0.001}_{-0.001}$ & $62.3^{+0.2}_{-0.2}$ \\
#  & F814W & $0.95^{+0.03}_{-0.03}$ & $3.79^{+0.06}_{-0.06}$ & $0.777^{+0.004}_{-0.004}$ & $66.8^{+0.6}_{-0.6}$ \\
#  & F475X & $0.65^{+0.03}_{-0.03}$ & $5.97^{+0.02}_{-0.05}$ & $0.703^{+0.017}_{-0.017}$ & $73.1^{+1.8}_{-1.8}$ \\
# \hline
# J2325-5229 & F160W & $0.79^{+0.02}_{-0.02}$ & $1.82^{+0.04}_{-0.04}$ & $0.796^{+0.002}_{-0.002}$ & $144.9^{+0.4}_{-0.4}$ \\
#  & F160W & $0.08^{+0.01}_{-0.01}$ & $5.96^{+0.03}_{-0.06}$ & $0.851^{+0.006}_{-0.006}$ & $138.8^{+1.4}_{-1.3}$ \\
#  & F160W Composite & $0.46^{+0.01}_{-0.01}$ & $--$ & $0.807^{+0.001}_{-0.002}$ & $144.2^{+0.2}_{-0.3}$ \\
#  & F814W & $1.44^{+0.10}_{-0.09}$ & $4.80^{+0.12}_{-0.11}$ & $0.838^{+0.005}_{-0.005}$ & $145.4^{+0.9}_{-0.9}$ \\
#  & F475X & $2.97^{+0.18}_{-0.21}$ & $5.94^{+0.05}_{-0.10}$ & $0.891^{+0.016}_{-0.015}$ & $147.4^{+4.2}_{-4.4}$ \\
# \hline
# \end{tabular*}

# %% [markdown]
# # Source Light

# %%
import pickle
import numpy as np

def get_median_and_uncertainties(samples):
        median = np.percentile(samples, 50)
        lower = median - np.percentile(samples, 16)
        upper = np.percentile(samples, 84) - median
        return median, lower, upper
    

names = ['J0407-5006', 
        'J0602-4335',
         'J0806+2006', 
         'J1001+5027', 
         'J1442+4055', 
         'J1515+1511', 
         'J1620+1203', 
         'J2325-5229'
]

# LaTeX header
print("\\begin{table}[htb]")
print("\\centering")
print("\\caption{F160W best-fit source light model parameters}")
print("\\label{tab:source_light_params_f814w}")
print("\\begin{tabular}lcccc}")
print("\\hline")
print("Lens System & $R_{\\text{S\\'ersic}}$ [arcsec] & $n_{\\text{S\\'ersic}}$ & $q$ \\\\")
print("\\hline")

class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        # Handle missing LikelihoodAddition class
        if name == 'LikelihoodAddition':
            class LikelihoodAddition:
                pass
            return LikelihoodAddition
        return super().find_class(module, name)

for i, name in enumerate(names):
    filename = f"../joint_modeling/{name}/{name}_joint.pkl"
    with open(filename, "rb") as f:
        loaded_data = CustomUnpickler(f).load()

    chain_list = loaded_data.get('chain_list')
    sampler_type, samples_mcmc, param_mcmc, dist_mcmc = chain_list[-1]

    param_names = ['R_sersic_source_light0', 'n_sersic_source_light0', 'e1_source_light0', 'e2_source_light0']
    indices = [param_mcmc.index(p) for p in param_names]

    r_chain = samples_mcmc[:, indices[0]]
    n_chain = samples_mcmc[:, indices[1]]
    e1_chain = samples_mcmc[:, indices[2]]
    e2_chain = samples_mcmc[:, indices[3]]

    e_chain = np.sqrt(e1_chain**2 + e2_chain**2)
    q_chain = (1 - e_chain) / (1 + e_chain)

    r_median, r_lower, r_upper = get_median_and_uncertainties(r_chain)
    n_median, n_lower, n_upper = get_median_and_uncertainties(n_chain)
    q_median, q_lower, q_upper = get_median_and_uncertainties(q_chain)

    # Print table row
    print(f"{name} & "
          f"${r_median:.2f}^{{+{r_upper:.2f}}}_{{-{r_lower:.2f}}}$ & "
          f"${n_median:.2f}^{{+{n_upper:.2f}}}_{{-{n_lower:.2f}}}$ & "
          f"${q_median:.2f}^{{+{q_upper:.2f}}}_{{-{q_lower:.2f}}}$ & \\\\")

print("\\hline")
print("\\end{tabular}")
print("\\end{table}")
# Out:
# \begin{table}[htb]
# \centering
# \caption{F160W best-fit source light model parameters}
# \label{tab:source_light_params_f814w}
# \begin{tabular}lcccc}
# \hline
# Lens System & $R_{\text{S\'ersic}}$ [arcsec] & $n_{\text{S\'ersic}}$ & $q$ \\
# \hline
# J0407-5006 & $0.20^{+0.03}_{-0.03}$ & $3.93^{+0.05}_{-0.11}$ & $0.76^{+0.02}_{-0.02}$ & \\
# J0602-4335 & $0.11^{+0.01}_{-0.01}$ & $0.53^{+0.04}_{-0.02}$ & $0.63^{+0.02}_{-0.02}$ & \\
# J0806+2006 & $0.08^{+0.01}_{-0.00}$ & $3.85^{+0.11}_{-0.28}$ & $0.56^{+0.07}_{-0.07}$ & \\
# J1001+5027 & $0.40^{+0.01}_{-0.00}$ & $0.56^{+0.02}_{-0.02}$ & $0.76^{+0.07}_{-0.02}$ & \\
# J1442+4055 & $0.43^{+0.02}_{-0.02}$ & $0.77^{+0.09}_{-0.08}$ & $0.74^{+0.03}_{-0.03}$ & \\
# J1515+1511 & $0.47^{+0.10}_{-0.08}$ & $3.86^{+0.09}_{-0.32}$ & $0.48^{+0.04}_{-0.03}$ & \\
# J1620+1203 & $0.32^{+0.02}_{-0.02}$ & $2.01^{+0.26}_{-0.20}$ & $0.84^{+0.05}_{-0.05}$ & \\
# J2325-5229 & $1.30^{+0.09}_{-0.07}$ & $0.51^{+0.02}_{-0.01}$ & $0.67^{+0.01}_{-0.01}$ & \\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# # Mass Components

# %%
import pickle
import h5py
import numpy as np
import os
from lenstronomy.Util.param_util import ellipticity2phi_q
from lenstronomy.Util.param_util import shear_cartesian2polar

names = [
        'J0407-5006',
        'J0602-4335',
        'J0806+2006', 
        'J1001+5027',
         'J1442+4055', 
         'J1515+1511', 
         'J1620+1203', 
         'J2325-5229'
        ]

class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        # Handle missing LikelihoodAddition class
        if name == 'LikelihoodAddition':
            class LikelihoodAddition:
                pass
            return LikelihoodAddition
        return super().find_class(module, name)

def get_median_and_uncertainties(samples):
    median = np.percentile(samples, 50)
    lower = median - np.percentile(samples, 16)
    upper = np.percentile(samples, 84) - median
    return median, lower, upper

def summarize_chain(chain, fmt=".2f"):
    med, lo, up = get_median_and_uncertainties(chain)

    return f"${med:{fmt}}^{{+{up:{fmt}}}}_{{-{lo:{fmt}}}}$"

# Combined LaTeX Table 
print("\\begin{table*}[htb]")
print("\\centering")
print("\\caption{Lens model and cosmological parameters for each doubly imaged quasar system.}")
print("\\label{tab:joint_results}")
print("\\begin{tabular*}{\\textwidth}{@{\\extracolsep{\\fill}}lcccccccccc}")
print("\\hline")
print("Lens System & $\\theta_E$ [arcsec] & $q_{\\text{mass}}$ & "
      "$\\phi_{\\text{mass}}$ [deg] & $\\gamma_{\\text{ext}}$ & $\\phi_{\\text{ext}}$ & $z_l$ & $z_s$ & "
      "$\\Delta \\Phi_{AB}$ [arcsec$^2$] \\\\")
print("\\hline")

for i, name in enumerate(names):
    # Defaults
    theta_E = q_mass = phi_mass = gamma = "--"
    dphi_fmt = dt_fmt = "--"

    # Load lens model results 
    pkl_file = f"../joint_modeling/{name}/{name}_joint.pkl"
    with open(pkl_file, "rb") as f:
        loaded_data = CustomUnpickler(f).load()

    chain_list = loaded_data.get('chain_list')
    sampler_type, samples_mcmc, param_mcmc, dist_mcmc = chain_list[-1]

    # Handle J1001+5027 separately
    if name == "J1001+5027":
    # Use main lens (lens0)
        param_names_mass = ['theta_E_lens0', 'e1_lens0', 'e2_lens0', 'gamma1_lens2', 'gamma2_lens2']
    else:
        param_names_mass = ['theta_E_lens0', 'e1_lens0', 'e2_lens0', 'gamma1_lens1', 'gamma2_lens1']

    indices = [param_mcmc.index(p) for p in param_names_mass]

    theta_E_chain = samples_mcmc[:, indices[0]]
    e1_chain = samples_mcmc[:, indices[1]]
    e2_chain = samples_mcmc[:, indices[2]]
    gamma1_chain = samples_mcmc[:, indices[3]]
    gamma2_chain = samples_mcmc[:, indices[4]]

    e_chain = np.sqrt(e1_chain**2 + e2_chain**2)
    q_mass_chain = (1 - e_chain) / (1 + e_chain)
    phi_mass_chain = 0.5 * np.arctan2(e2_chain, e1_chain) * 180 / np.pi

    phi_mass_chain, q_mass_chain = ellipticity2phi_q(e1_chain, e2_chain)
    phi_mass_chain = (phi_mass_chain * 180/np.pi) % 180

    phi_ext_chain, gamma_chain = shear_cartesian2polar(gamma1_chain, gamma2_chain)
    phi_ext_chain = (phi_ext_chain * 180/np.pi) % 180

    theta_E = summarize_chain(theta_E_chain, fmt=".3f")
    q_mass = summarize_chain(q_mass_chain)
    phi_mass = summarize_chain(phi_mass_chain, fmt=".1f")
    gamma = summarize_chain(gamma_chain, fmt='.3f') 
    phi_ext = summarize_chain(phi_ext_chain, fmt=".1f")


    # Load cosmological results
    h5_file = f"../joint_modeling/{name}/{name}_cosmo.hdf5"
    with h5py.File(h5_file, "r") as f:
            kwargs = {key: f[key][()] for key in f}

    dphi_chain = kwargs['dphi_list']
    dt_chain = kwargs['dt_list']

    dphi_median, dphi_lower, dphi_upper = get_median_and_uncertainties(dphi_chain)
    dt_median, dt_lower, dt_upper = get_median_and_uncertainties(dt_chain)

    dphi_fmt = f"${dphi_median:.3f}^{{+{dphi_upper:.3f}}}_{{-{dphi_lower:.3f}}}$"
    dt_fmt = f"${dt_median:.1f}^{{+{dt_upper:.1f}}}_{{-{dt_lower:.1f}}}$"


    # Combine everything into one row
    #z_l_fmt = f"${z_l[i]}$"
    #z_s_fmt = f"${z_s[i]}$"

    print(f"{name} & {theta_E} & {q_mass} & {phi_mass} & "
          f"{gamma} & {phi_ext} & {dphi_fmt} \\\\ [3pt]")

print("\\hline")
print("\\end{tabular*}")
print("\\end{table*}")
# Out:
# \begin{table*}[htb]
# \centering
# \caption{Lens model and cosmological parameters for each doubly imaged quasar system.}
# \label{tab:joint_results}
# \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}lcccccccccc}
# \hline
# Lens System & $\theta_E$ [arcsec] & $q_{\text{mass}}$ & $\phi_{\text{mass}}$ [deg] & $\gamma_{\text{ext}}$ & $\phi_{\text{ext}}$ & $z_l$ & $z_s$ & $\Delta \Phi_{AB}$ [arcsec$^2$] \\
# \hline
# J0407-5006 & $0.862^{+0.012}_{-0.014}$ & $0.99^{+0.01}_{-0.01}$ & $111.6^{+7.8}_{-8.1}$ & $0.026^{+0.007}_{-0.005}$ & $109.4^{+14.9}_{-19.1}$ & $0.968^{+0.014}_{-0.013}$ \\ [3pt]
# J0602-4335 & $0.906^{+0.005}_{-0.006}$ & $0.65^{+0.02}_{-0.02}$ & $137.4^{+0.8}_{-4.2}$ & $0.052^{+0.011}_{-0.005}$ & $131.0^{+1.9}_{-9.7}$ & $-0.548^{+0.012}_{-0.011}$ \\ [3pt]
# J0806+2006 & $0.783^{+0.014}_{-0.015}$ & $0.88^{+0.05}_{-0.06}$ & $66.6^{+7.3}_{-8.7}$ & $0.080^{+0.025}_{-0.026}$ & $70.7^{+4.6}_{-5.0}$ & $-0.493^{+0.013}_{-0.018}$ \\ [3pt]
# J1001+5027 & $1.395^{+0.004}_{-0.004}$ & $0.74^{+0.04}_{-0.02}$ & $140.7^{+2.8}_{-19.6}$ & $0.116^{+0.008}_{-0.049}$ & $158.6^{+1.5}_{-5.2}$ & $-2.366^{+0.011}_{-0.010}$ \\ [3pt]
# J1442+4055 & $1.032^{+0.007}_{-0.007}$ & $0.80^{+0.02}_{-0.03}$ & $81.1^{+4.7}_{-3.6}$ & $0.028^{+0.011}_{-0.008}$ & $121.7^{+7.9}_{-9.5}$ & $-0.608^{+0.007}_{-0.009}$ \\ [3pt]
# J1515+1511 & $0.943^{+0.013}_{-0.009}$ & $0.70^{+0.05}_{-0.04}$ & $75.1^{+4.1}_{-2.9}$ & $0.037^{+0.008}_{-0.009}$ & $122.8^{+7.7}_{-4.2}$ & $-1.195^{+0.039}_{-0.030}$ \\ [3pt]
# J1620+1203 & $1.429^{+0.017}_{-0.016}$ & $0.76^{+0.03}_{-0.03}$ & $58.3^{+3.7}_{-3.7}$ & $0.040^{+0.016}_{-0.012}$ & $31.6^{+10.6}_{-11.3}$ & $2.394^{+0.055}_{-0.053}$ \\ [3pt]
# J2325-5229 & $1.466^{+0.002}_{-0.002}$ & $0.94^{+0.02}_{-0.02}$ & $145.8^{+4.9}_{-5.0}$ & $0.039^{+0.004}_{-0.004}$ & $82.9^{+3.0}_{-2.7}$ & $-0.697^{+0.004}_{-0.005}$ \\ [3pt]
# \hline
# \end{tabular*}
# \end{table*}

# %% [markdown]
# # Compute Bayesian Inference Criterion (BIC) for source vs. no source models

# %%
import pickle
import numpy as np
import h5py
import os
from astropy.io import fits
from lenstronomy.Workflow.fitting_sequence import FittingSequence

class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        # Handle missing LikelihoodAddition class
        if name == 'LikelihoodAddition':
            # Return a callable that does nothing (returns 0)
            class LikelihoodAddition:
                def __call__(self, *args, **kwargs):
                    return 0.0
            return LikelihoodAddition
        return super().find_class(module, name)

# Helper functions
def get_back_rms(system, filter):
    """Get background RMS from the cutout FITS file header"""
    if filter == 'F160W':
        path_to_fits = f'../cutout_data/{system}/{filter}/{system}_{filter}_cutout.fits'
    else:
        path_to_fits = f'../joint_modeling/{system}/{system}_{filter}_cutout.fits'

    with fits.open(path_to_fits) as hdul:
        if 'BACK_RMS' in hdul[0].header:
            return hdul[0].header['BACK_RMS']

def summarize_flux_from_sigma(flux, sigma, back_rms=None):
    """
    Given flux and asymmetric sigma = [upper, lower],
    return median, -err, +err, S/N.
    If back_rms is provided, add it in quadrature to the uncertainty.
    """
    sigma_up, sigma_lo = sigma
    
    # Add background RMS noise in quadrature if available
    if back_rms is not None:
        sigma_up = np.sqrt(sigma_up**2 + back_rms**2)
        sigma_lo = np.sqrt(sigma_lo**2 + back_rms**2)
    
    sigma_mean = 0.5 * (sigma_up + sigma_lo)
    snr = flux / sigma_mean if sigma_mean > 0 else 0.0
    return flux, sigma_lo, sigma_up, snr

# Systems and filters
systems = [
    'J0806+2006', 
    'J1442+4055', 
    'J1515+1511',
    'J2325-5229'
]
filters = ["F160W", "F814W", "F475X"]

# Main loop
for name in systems:
    fn_ns = f'../no_source/{name}/{name}_joint.pkl'
    fn_s  = f'../joint_modeling/{name}/{name}_joint.pkl'
    fn_phot = f'../joint_modeling/{name}/{name}_photometry.hdf5'
    
    with open(fn_ns, 'rb') as f:
        data_ns = CustomUnpickler(f).load()
    with open(fn_s, 'rb') as f:
        data_s = CustomUnpickler(f).load()
    
    # No-source model
    fs_ns = FittingSequence(
        kwargs_data_joint=data_ns['kwargs_data_joint'],
        kwargs_model=data_ns['kwargs_model'],
        kwargs_constraints=data_ns['kwargs_constraints'],
        kwargs_likelihood=data_ns['kwargs_likelihood'],
        kwargs_params=data_ns['kwargs_params'],
        verbose=False
    )
    fs_ns.update_state(data_ns['kwargs_result'])
    logL_ns = fs_ns.best_fit_likelihood()
    BIC_ns = fs_ns.bic
    
    # Source model 
    fs_s = FittingSequence(
        kwargs_data_joint=data_s['kwargs_data_joint'],
        kwargs_model=data_s['kwargs_model'],
        kwargs_constraints=data_s['kwargs_constraints'],
        kwargs_likelihood=data_s['kwargs_likelihood'],
        kwargs_params=data_s['kwargs_params'],
        verbose=False
    )
    fs_s.update_state(data_s['kwargs_result'])
    logL_s = fs_s.best_fit_likelihood()
    BIC_s = fs_s.bic
    delta_bic = BIC_ns - BIC_s
    
    # Print diagnostics
    print(f"{name}")
    print(f"  logL (no source): {logL_ns:.2f}")
    print(f"  logL (source)   : {logL_s:.2f}")
    print(f"  ΔBIC            : {delta_bic:.1f}")
    
    # Host photometry
    
    with h5py.File(fn_phot, "r") as f:
        for filt in filters:
            
            g = f[filt]
            mag_key   = "host_lensed_mag"
            flux_key  = "host_lensed_flux"
            sigma_key = "host_lensed_flux_sigma"
            
            if mag_key not in g or np.isnan(g[mag_key][()]):
                print(f"    {filt}: host not detected (photometry)")
                continue
            
            flux = g[flux_key][()]
            sigma = g[sigma_key][()]
            
            # Get background RMS for this system/filter
            back_rms = get_back_rms(name, filt)
            
            # Calculate flux and SNR with background noise included
            med, lo, up, snr = summarize_flux_from_sigma(flux, sigma, back_rms)
            
            rms_str = f" (with bkg RMS)"
            print(
                f"    {filt} host: "
                f"{med:.3g} (+{up:.3g}/-{lo:.3g}), "
                f"S/N ≈ {snr:.1f}{rms_str}"
            )
    print()
# Out:
# /Users/rbrady0110/micromamba/envs/doubles/lib/python3.13/site-packages/lenstronomy/Data/psf.py:95: UserWarning: Input PSF model has at least one negative element, which is unphysical except for a PSF of an interferometric array.
#   warnings.warn(
# J0407-5006
#   logL (no source): -21896.58
#   logL (source)   : -15806.27
#   ΔBIC            : 12131.1
#     F160W host: 280 (+5.05/-5.65), S/N ≈ 52.4 (with bkg RMS)
#     F814W host: 27.4 (+0.903/-0.986), S/N ≈ 29.0 (with bkg RMS)
#     F475X host: 22.8 (+0.639/-0.527), S/N ≈ 39.1 (with bkg RMS)
#
# J0602-4335
#   logL (no source): -25659.13
#   logL (source)   : -23708.49
#   ΔBIC            : 3849.1
#     F160W host: 96.6 (+2/-1.54), S/N ≈ 54.6 (with bkg RMS)
#     F814W host: 1.64 (+0.317/-0.286), S/N ≈ 5.4 (with bkg RMS)
#     F475X host: 1.43 (+0.287/-0.276), S/N ≈ 5.1 (with bkg RMS)
#
# J0806+2006
#   logL (no source): -10236.20
#   logL (source)   : -9962.19
#   ΔBIC            : 497.1
#     F160W host: 86.5 (+5.79/-5.46), S/N ≈ 15.4 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X: host not detected (photometry)
#
# J1001+5027
#   logL (no source): -39318.75
#   logL (source)   : -29262.78
#   ΔBIC            : 20047.5
#     F160W host: 521 (+4.65/-4.25), S/N ≈ 117.1 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X host: 44.9 (+0.624/-0.695), S/N ≈ 68.0 (with bkg RMS)
#
# J1442+4055
#   logL (no source): -11513.98
#   logL (source)   : -10834.92
#   ΔBIC            : 1307.8
#     F160W host: 329 (+6.88/-7.82), S/N ≈ 44.8 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X host: 10.1 (+0.897/-0.857), S/N ≈ 11.5 (with bkg RMS)
#
# J1515+1511
#   logL (no source): -11314.99
#   logL (source)   : -10771.37
#   ΔBIC            : 1036.5
#     F160W host: 82.6 (+3.44/-3.83), S/N ≈ 22.7 (with bkg RMS)
#     F814W host: 5.37 (+0.482/-0.631), S/N ≈ 9.7 (with bkg RMS)
#     F475X host: 9.11 (+0.826/-0.719), S/N ≈ 11.8 (with bkg RMS)
#
# J1620+1203
#   logL (no source): -24288.70
#   logL (source)   : -16919.96
#   ΔBIC            : 14685.5
#     F160W host: 130 (+3.92/-3.98), S/N ≈ 32.9 (with bkg RMS)
#     F814W host: 8.84 (+0.356/-0.314), S/N ≈ 26.4 (with bkg RMS)
#     F475X host: 19 (+0.679/-0.751), S/N ≈ 26.6 (with bkg RMS)
#
# J2325-5229
#   logL (no source): -20147.12
#   logL (source)   : -15985.45
#   ΔBIC            : 8051.4
#     F160W host: 421 (+13.8/-12.2), S/N ≈ 32.3 (with bkg RMS)
#     F814W: host not detected (photometry)
#     F475X: host not detected (photometry)

# %% [markdown]
# # Observational Information

# %%
from astropy.io import fits
from astropy.time import Time
import numpy as np

systems = [
    'J0407-5006', 'J0602-4335', 'J0806+2006', 'J1001+5027',
    'J1442+4055', 'J1515+1511', 'J1620+1203', 'J2325-5229'
]
filters = ["F160W", "F814W", "F475X"]

def get_hdr(system, filt):
    """Get FITS header for a given system and filter."""
    if filt == 'F160W':
        path_to_fits = f'../cutout_data/{system}/{filt}/{system}_{filt}_cutout.fits'
    else:
        path_to_fits = f'../joint_modeling/{system}/{system}_{filt}_cutout.fits'
    
    with fits.open(path_to_fits) as hdul:
        hdr = hdul[0].header
    return hdr

def format_date(mjd):
    """Convert MJD to readable date format."""
    t = Time(mjd, format='mjd')
    return t.iso.split()[0]  # Return just the date part

# Create LaTeX table
print("\\begin{table*}")
print("\\centering")
print("\\caption{HST Observation Details for Strong Lens Systems}")
print("\\begin{tabular}{lcccc}")
print("\\hline\\hline")
print("System & Filter & Instrument & Exposure Time (s) & Observation Date \\\\")
print("\\hline")

for system in systems:
    row_started = False
    
    for filt in filters:
        hdr = get_hdr(system, filt)
        
        # Extract relevant information
        exptime = hdr.get('EXPTIME', 'N/A')
        if exptime != 'N/A':
            exptime = f"{exptime:.1f}"
        
        expstart = hdr.get('EXPSTART', None)
        if expstart is not None:
            obs_date = format_date(expstart)
        else:
            obs_date = "N/A"
        
        instrument = hdr.get('INSTRUME', 'N/A')
        
        detector = hdr.get('DETECTOR', '')
        if detector:
            instrument = f"{instrument}/{detector}"
                
        if not row_started:
            print(f"{system} & {filt} & {instrument} & {exptime} & {obs_date} \\\\")
            row_started = True
        else:
            print(f" & {filt} & {instrument} & {exptime} & {obs_date} \\\\")
    
    print("\\hline")

print("\\end{tabular}")
print("\\label{tab:observations}")
print("\\end{table*}")
# Out:
# \begin{table*}
# \centering
# \caption{HST Observation Details for Strong Lens Systems}
# \begin{tabular}{lcccc}
# \hline\hline
# System & Filter & Instrument & Exposure Time (s) & Observation Date \\
# \hline
# J0407-5006 & F160W & WFC3/IR & 4393.9 & 2024-02-28 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2024-02-28 \\
#  & F475X & WFC3/UVIS & 988.0 & 2024-02-28 \\
# \hline
# J0602-4335 & F160W & WFC3/IR & 4393.9 & 2023-08-01 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2023-08-01 \\
#  & F475X & WFC3/UVIS & 793.0 & 2023-08-01 \\
# \hline
# J0806+2006 & F160W & WFC3/IR & 4393.9 & 2023-04-04 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2023-05-16 \\
#  & F475X & WFC3/UVIS & 676.0 & 2023-04-04 \\
# \hline
# J1001+5027 & F160W & WFC3/IR & 1597.7 & 2024-12-20 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2023-12-08 \\
#  & F475X & WFC3/UVIS & 1397.0 & 2023-12-08 \\
# \hline
# J1442+4055 & F160W & WFC3/IR & 4393.9 & 2023-07-05 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2023-11-14 \\
#  & F475X & WFC3/UVIS & 771.0 & 2023-07-05 \\
# \hline
# J1515+1511 & F160W & WFC3/IR & 4393.9 & 2023-06-28 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2023-08-23 \\
#  & F475X & WFC3/UVIS & 674.0 & 2023-06-28 \\
# \hline
# J1620+1203 & F160W & WFC3/IR & 4393.9 & 2023-06-27 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2023-06-27 \\
#  & F475X & WFC3/UVIS & 615.0 & 2023-06-27 \\
# \hline
# J2325-5229 & F160W & WFC3/IR & 4393.9 & 2023-08-19 \\
#  & F814W & WFC3/UVIS & 1428.0 & 2023-08-19 \\
#  & F475X & WFC3/UVIS & 988.0 & 2023-08-19 \\
# \hline
# \end{tabular}
# \label{tab:observations}
# \end{table*}
